# %% [markdown]
# <a href="https://colab.research.google.com/github/icahlatif/My_List/blob/master/42618021_UAS_CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

import os
import random
import shutil

import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img

import matplotlib.pyplot as plt

# %%
train_dir = "/content/drive/MyDrive/Indo_snake/Training/"
test_dir = "/content/drive/MyDrive/Indo_snake/Testing/"

# %%
# Displaying random image from the dataset
fig, ax = plt.subplots(4, 5, figsize=(15, 10))

sample_paper = random.choice(os.listdir(train_dir + "Boiga Dendrophila  (Ular Cincin Emas)"))
image = load_img(train_dir + "Boiga Dendrophila  (Ular Cincin Emas)/" + sample_paper)
ax[0, 0].imshow(image)
ax[0, 0].set_title("Ular Cincin")
ax[0, 0].axis("Off")

sample_paper = random.choice(os.listdir(train_dir + "Bungarus Candidus (Ular Weling)"))
image = load_img(train_dir + "Bungarus Candidus (Ular Weling)/" + sample_paper)
ax[0, 1].imshow(image)
ax[0, 1].set_title("Ular Weling")
ax[0, 1].axis("Off")

sample_paper = random.choice(os.listdir(train_dir + "Bungarus Fasciatus (Ular Welang)"))
image = load_img(train_dir + "Bungarus Fasciatus (Ular Welang)/" + sample_paper)
ax[0, 2].imshow(image)
ax[0, 2].set_title("Ular Welang")
ax[0, 2].axis("Off")

sample_paper = random.choice(os.listdir(train_dir + "Bungarus Flaviceps (Krait Kepala Merah)"))
image = load_img(train_dir + "Bungarus Flaviceps (Krait Kepala Merah)/" + sample_paper)
ax[0, 3].imshow(image)
ax[0, 3].set_title("Ular Krait")
ax[0, 3].axis("Off")

sample_paper = random.choice(os.listdir(train_dir + "Calamaria Schlegeli (Ular Buluh Berkepala Merah)"))
image = load_img(train_dir + "Calamaria Schlegeli (Ular Buluh Berkepala Merah)/" + sample_paper)
ax[0, 4].imshow(image)
ax[0, 4].set_title("Ular Calamaria")
ax[0, 4].axis("Off")

sample_paper = random.choice(os.listdir(train_dir + "Calliophis Bivirgatus (Ular Cabai Besar)"))
image = load_img(train_dir + "Calliophis Bivirgatus (Ular Cabai Besar)/" + sample_paper)
ax[1, 0].imshow(image)
ax[1, 0].set_title("Ular Cabai Besar")
ax[1, 0].axis("Off")

sample_paper = random.choice(os.listdir(train_dir + "Calliophis Intestinalis (Ular Cabai Kecil)"))
image = load_img(train_dir + "Calliophis Intestinalis (Ular Cabai Kecil)/" + sample_paper)
ax[1, 1].imshow(image)
ax[1, 1].set_title("Ular Cabai Kecil")
ax[1, 1].axis("Off")

sample_paper = random.choice(os.listdir(train_dir + "Calloselasma Rhodostoma (Ular Tanah)"))
image = load_img(train_dir + "Calloselasma Rhodostoma (Ular Tanah)/" + sample_paper)
ax[1, 2].imshow(image)
ax[1, 2].set_title("Ular Tanah")
ax[1, 2].axis("Off")

sample_paper = random.choice(os.listdir(train_dir + "Daboia Siamensis (Ular Bandotan Puspa)"))
image = load_img(train_dir + "Daboia Siamensis (Ular Bandotan Puspa)/" + sample_paper)
ax[1, 3].imshow(image)
ax[1, 3].set_title("Ular Bandotan Puspa")
ax[1, 3].axis("Off")

sample_paper = random.choice(os.listdir(train_dir + "Gonyosoma Oxycephalum (Ular Bajing)"))
image = load_img(train_dir + "Gonyosoma Oxycephalum (Ular Bajing)/" + sample_paper)
ax[1, 4].imshow(image)
ax[1, 4].set_title("Ular Bajing")
ax[1, 4].axis("Off")

sample_paper = random.choice(os.listdir(train_dir + "Hydrophis Belcheri (Ular Laut Belcher )"))
image = load_img(train_dir + "Hydrophis Belcheri (Ular Laut Belcher )/" + sample_paper)
ax[2, 0].imshow(image)
ax[2, 0].set_title("Ular Belcher")
ax[2, 0].axis("Off")

sample_paper = random.choice(os.listdir(train_dir + "Lycodon Subcinctus (Ular Cicak)"))
image = load_img(train_dir + "Lycodon Subcinctus (Ular Cicak)/" + sample_paper)
ax[2, 1].imshow(image)
ax[2, 1].set_title("Ular Cicak")
ax[2, 1].axis("Off")

sample_paper = random.choice(os.listdir(train_dir + "Naja sumatrana (Ular Kobra Sumatra)"))
image = load_img(train_dir + "Naja sumatrana (Ular Kobra Sumatra)/" + sample_paper)
ax[2, 2].imshow(image)
ax[2, 2].set_title("Ular Kobra Sumatra")
ax[2, 2].axis("Off")

sample_paper = random.choice(os.listdir(train_dir + "Ophiophagus Hannah (King Cobra)"))
image = load_img(train_dir + "Ophiophagus Hannah (King Cobra)/" + sample_paper)
ax[2, 3].imshow(image)
ax[2, 3].set_title("King Cobra")
ax[2, 3].axis("Off")

sample_paper = random.choice(os.listdir(train_dir + "Oxyuranus Scutellatus (Ular Taipan Pesisir)"))
image = load_img(train_dir + "Oxyuranus Scutellatus (Ular Taipan Pesisir)/" + sample_paper)
ax[2, 4].imshow(image)
ax[2, 4].set_title("Ular Taipan Pesisir")
ax[2, 4].axis("Off")

ax[3, 0].axis("Off")
sample_paper = random.choice(os.listdir(train_dir + "Rhabdophis Subminiatus (Ular Picung)"))
image = load_img(train_dir + "Rhabdophis Subminiatus (Ular Picung)/" + sample_paper)
ax[3, 1].imshow(image)
ax[3, 1].set_title("Ular Picung")
ax[3, 1].axis("Off")
ax[3, 2].axis("Off")
sample_paper = random.choice(os.listdir(train_dir + "Trimeresurus Albolabris (Ular Bangkai Laut)"))
image = load_img(train_dir + "Trimeresurus Albolabris (Ular Bangkai Laut)/" + sample_paper)
ax[3, 3].imshow(image)
ax[3, 3].set_title("Ular Bangkai Laut")
ax[3, 3].axis("Off")
ax[3, 4].axis("Off")
# Out:
# (0.0, 1.0, 0.0, 1.0)

# %%
train_datagen = ImageDataGenerator(
      rescale=1./255,
      rotation_range=30,
      width_shift_range=0.4, # Shifting image width by 40%
      height_shift_range=0.4,# Shifting image height by 40%
      shear_range=0.2,       # Rotation across X-axis by 20%
      zoom_range=0.3,        # Image zooming by 30%
      vertical_flip = True,
      horizontal_flip=True)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size = (150, 200),
    class_mode = 'categorical',
    batch_size = 32
)

test_datagen = ImageDataGenerator(
      rescale=1./255)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size = (150, 200),
    class_mode = 'categorical',
    batch_size = 32
)
# Out:
# Found 1570 images belonging to 17 classes.
# Found 337 images belonging to 17 classes.

# %%
from keras.layers import Dense, Dropout, Flatten
model = tf.keras.models.Sequential([
    
    tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(150, 200, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),
    Dropout(0.25),
    
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    Dropout(0.25),
    
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    Dropout(0.25),
    
    tf.keras.layers.Flatten(),
    
    tf.keras.layers.Dense(32, activation='relu'),
    Dropout(0.25),
    tf.keras.layers.Dense(17, activation='softmax')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 148, 198, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 74, 99, 32)        0
# _________________________________________________________________
# module_wrapper (ModuleWrappe (None, 74, 99, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 72, 97, 32)        9248
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 36, 48, 32)        0
# _________________________________________________________________
# module_wrapper_1 (ModuleWrap (None, 36, 48, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 34, 46, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 17, 23, 64)        0
# _________________________________________________________________
# module_wrapper_2 (ModuleWrap (None, 17, 23, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 15, 21, 128)       73856
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 7, 10, 128)        0
# _________________________________________________________________
# module_wrapper_3 (ModuleWrap (None, 7, 10, 128)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 8960)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               1147008
# _________________________________________________________________
# module_wrapper_4 (ModuleWrap (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               16512
# _________________________________________________________________
# module_wrapper_5 (ModuleWrap (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 17)                2193
# =================================================================
# Total params: 1,268,209
# Trainable params: 1,268,209
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss = 'categorical_crossentropy',
              optimizer = 'adam',
              metrics = ['accuracy'])

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=30)

# %%
history = model.fit_generator(train_generator,
                              epochs=200,
                              verbose=1,
                              validation_data=test_generator,
                              callbacks = [es])
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1940: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/200
# 50/50 [==============================] - 562s 11s/step - loss: 2.8414 - accuracy: 0.0643 - val_loss: 2.8332 - val_accuracy: 0.0593
# Epoch 2/200
# 50/50 [==============================] - 87s 2s/step - loss: 2.8328 - accuracy: 0.0650 - val_loss: 2.8332 - val_accuracy: 0.0593
# Epoch 3/200
# 50/50 [==============================] - 88s 2s/step - loss: 2.8305 - accuracy: 0.0777 - val_loss: 2.8333 - val_accuracy: 0.0623
# Epoch 4/200
# 50/50 [==============================] - 88s 2s/step - loss: 2.8307 - accuracy: 0.0682 - val_loss: 2.8330 - val_accuracy: 0.0593
# Epoch 5/200
# 50/50 [==============================] - 87s 2s/step - loss: 2.8302 - accuracy: 0.0745 - val_loss: 2.8354 - val_accuracy: 0.0593
# Epoch 6/200
# 50/50 [==============================] - 87s 2s/step - loss: 2.8319 - accuracy: 0.0732 - val_loss: 2.8313 - val_accuracy: 0.0742
# Epoch 7/200
# 50/50 [==============================] - 88s 2s/step - loss: 2.8227 - accuracy: 0.0911 - val_loss: 2.8150 - val_accuracy: 0.0593
# Epoch 8/200
# 50/50 [==============================] - 88s 2s/step - loss: 2.7985 - accuracy: 0.0885 - val_loss: 2.7638 - val_accuracy: 0.0890
# Epoch 9/200
# 50/50 [==============================] - 88s 2s/step - loss: 2.7466 - accuracy: 0.1070 - val_loss: 2.7154 - val_accuracy: 0.0861
# Epoch 10/200
# 50/50 [==============================] - 88s 2s/step - loss: 2.6924 - accuracy: 0.1166 - val_loss: 2.6889 - val_accuracy: 0.1009
# Epoch 11/200
# 50/50 [==============================] - 86s 2s/step - loss: 2.6585 - accuracy: 0.1331 - val_loss: 2.6046 - val_accuracy: 0.1157
# Epoch 12/200
# 50/50 [==============================] - 86s 2s/step - loss: 2.6472 - accuracy: 0.1204 - val_loss: 2.6166 - val_accuracy: 0.1187
# Epoch 13/200
# 50/50 [==============================] - 86s 2s/step - loss: 2.6132 - accuracy: 0.1312 - val_loss: 2.5843 - val_accuracy: 0.1365
# Epoch 14/200
# 50/50 [==============================] - 87s 2s/step - loss: 2.6001 - accuracy: 0.1268 - val_loss: 2.5522 - val_accuracy: 0.1187
# Epoch 15/200
# 50/50 [==============================] - 86s 2s/step - loss: 2.5812 - accuracy: 0.1357 - val_loss: 2.4912 - val_accuracy: 0.1276
# Epoch 16/200
# 50/50 [==============================] - 87s 2s/step - loss: 2.5234 - accuracy: 0.1497 - val_loss: 2.4477 - val_accuracy: 0.2077
# Epoch 17/200
# 50/50 [==============================] - 86s 2s/step - loss: 2.4779 - accuracy: 0.1656 - val_loss: 2.3708 - val_accuracy: 0.1899
# Epoch 18/200
# 50/50 [==============================] - 86s 2s/step - loss: 2.4469 - accuracy: 0.1726 - val_loss: 2.3621 - val_accuracy: 0.1632
# Epoch 19/200
# 50/50 [==============================] - 87s 2s/step - loss: 2.3978 - accuracy: 0.1994 - val_loss: 2.3528 - val_accuracy: 0.2018
# Epoch 20/200
# 50/50 [==============================] - 86s 2s/step - loss: 2.3647 - accuracy: 0.2032 - val_loss: 2.3200 - val_accuracy: 0.2047
# Epoch 21/200
# 50/50 [==============================] - 88s 2s/step - loss: 2.3580 - accuracy: 0.2025 - val_loss: 2.4317 - val_accuracy: 0.1869
# Epoch 22/200
# 50/50 [==============================] - 86s 2s/step - loss: 2.3506 - accuracy: 0.2166 - val_loss: 2.2608 - val_accuracy: 0.2226
# Epoch 23/200
# 50/50 [==============================] - 86s 2s/step - loss: 2.3192 - accuracy: 0.2172 - val_loss: 2.2713 - val_accuracy: 0.2196
# Epoch 24/200
# 50/50 [==============================] - 88s 2s/step - loss: 2.3194 - accuracy: 0.2172 - val_loss: 2.2218 - val_accuracy: 0.2374
# Epoch 25/200
# 50/50 [==============================] - 85s 2s/step - loss: 2.2529 - accuracy: 0.2318 - val_loss: 2.2208 - val_accuracy: 0.2404
# Epoch 26/200
# 50/50 [==============================] - 82s 2s/step - loss: 2.2872 - accuracy: 0.2293 - val_loss: 2.2987 - val_accuracy: 0.2285
# Epoch 27/200
# 50/50 [==============================] - 82s 2s/step - loss: 2.2508 - accuracy: 0.2382 - val_loss: 2.2331 - val_accuracy: 0.2374
# Epoch 28/200
# 50/50 [==============================] - 83s 2s/step - loss: 2.2394 - accuracy: 0.2389 - val_loss: 2.2150 - val_accuracy: 0.2522
# Epoch 29/200
# 50/50 [==============================] - 83s 2s/step - loss: 2.2088 - accuracy: 0.2478 - val_loss: 2.1730 - val_accuracy: 0.2582
# Epoch 30/200
# 50/50 [==============================] - 83s 2s/step - loss: 2.1876 - accuracy: 0.2682 - val_loss: 2.1335 - val_accuracy: 0.2641
# Epoch 31/200
# 50/50 [==============================] - 84s 2s/step - loss: 2.1688 - accuracy: 0.2701 - val_loss: 2.1816 - val_accuracy: 0.2641
# Epoch 32/200
# 50/50 [==============================] - 82s 2s/step - loss: 2.1980 - accuracy: 0.2497 - val_loss: 2.2242 - val_accuracy: 0.2374
# Epoch 33/200
# 50/50 [==============================] - 82s 2s/step - loss: 2.1290 - accuracy: 0.2631 - val_loss: 2.1321 - val_accuracy: 0.2730
# Epoch 34/200
# 50/50 [==============================] - 82s 2s/step - loss: 2.1425 - accuracy: 0.2662 - val_loss: 2.2157 - val_accuracy: 0.2404
# Epoch 35/200
# 50/50 [==============================] - 82s 2s/step - loss: 2.1267 - accuracy: 0.2809 - val_loss: 2.0763 - val_accuracy: 0.2819
# Epoch 36/200
# 50/50 [==============================] - 82s 2s/step - loss: 2.0655 - accuracy: 0.3070 - val_loss: 2.1300 - val_accuracy: 0.2700
# Epoch 37/200
# 50/50 [==============================] - 82s 2s/step - loss: 2.1321 - accuracy: 0.2675 - val_loss: 2.1224 - val_accuracy: 0.2374
# Epoch 38/200
# 50/50 [==============================] - 83s 2s/step - loss: 2.2509 - accuracy: 0.2580 - val_loss: 2.1991 - val_accuracy: 0.2671
# Epoch 39/200
# 50/50 [==============================] - 82s 2s/step - loss: 2.0914 - accuracy: 0.2854 - val_loss: 2.0746 - val_accuracy: 0.3027
# Epoch 40/200
# 50/50 [==============================] - 82s 2s/step - loss: 2.0569 - accuracy: 0.2994 - val_loss: 2.0246 - val_accuracy: 0.3175
# Epoch 41/200
# 50/50 [==============================] - 82s 2s/step - loss: 2.0663 - accuracy: 0.2994 - val_loss: 2.0020 - val_accuracy: 0.3234
# Epoch 42/200
# 50/50 [==============================] - 82s 2s/step - loss: 2.0508 - accuracy: 0.3102 - val_loss: 1.9715 - val_accuracy: 0.3591
# Epoch 43/200
# 50/50 [==============================] - 82s 2s/step - loss: 2.0472 - accuracy: 0.3210 - val_loss: 1.9797 - val_accuracy: 0.3442
# Epoch 44/200
# 50/50 [==============================] - 82s 2s/step - loss: 2.0013 - accuracy: 0.3242 - val_loss: 1.9767 - val_accuracy: 0.3264
# Epoch 45/200
# 50/50 [==============================] - 83s 2s/step - loss: 1.9593 - accuracy: 0.3293 - val_loss: 2.0212 - val_accuracy: 0.3116
# Epoch 46/200
# 50/50 [==============================] - 83s 2s/step - loss: 1.9694 - accuracy: 0.3446 - val_loss: 1.9012 - val_accuracy: 0.3887
# Epoch 47/200
# 50/50 [==============================] - 83s 2s/step - loss: 1.9311 - accuracy: 0.3490 - val_loss: 1.8911 - val_accuracy: 0.3828
# Epoch 48/200
# 50/50 [==============================] - 82s 2s/step - loss: 1.9839 - accuracy: 0.3306 - val_loss: 2.0489 - val_accuracy: 0.3027
# Epoch 49/200
# 50/50 [==============================] - 82s 2s/step - loss: 2.0046 - accuracy: 0.3306 - val_loss: 1.9027 - val_accuracy: 0.3531
# Epoch 50/200
# 50/50 [==============================] - 82s 2s/step - loss: 1.9011 - accuracy: 0.3643 - val_loss: 1.9596 - val_accuracy: 0.3472
# Epoch 51/200
# 50/50 [==============================] - 82s 2s/step - loss: 1.8938 - accuracy: 0.3777 - val_loss: 1.9358 - val_accuracy: 0.3442
# Epoch 52/200
# 50/50 [==============================] - 82s 2s/step - loss: 1.9267 - accuracy: 0.3452 - val_loss: 1.9247 - val_accuracy: 0.3294
# Epoch 53/200
# 50/50 [==============================] - 82s 2s/step - loss: 1.9355 - accuracy: 0.3490 - val_loss: 1.8745 - val_accuracy: 0.3917
# Epoch 54/200
# 50/50 [==============================] - 82s 2s/step - loss: 1.8814 - accuracy: 0.3497 - val_loss: 1.9074 - val_accuracy: 0.3264
# Epoch 55/200
# 50/50 [==============================] - 82s 2s/step - loss: 1.8944 - accuracy: 0.3828 - val_loss: 1.9482 - val_accuracy: 0.3442
# Epoch 56/200
# 50/50 [==============================] - 82s 2s/step - loss: 1.9092 - accuracy: 0.3541 - val_loss: 1.9644 - val_accuracy: 0.3442
# Epoch 57/200
# 50/50 [==============================] - 82s 2s/step - loss: 1.8410 - accuracy: 0.3790 - val_loss: 1.7739 - val_accuracy: 0.4065
# Epoch 58/200
# 50/50 [==============================] - 82s 2s/step - loss: 1.8207 - accuracy: 0.3975 - val_loss: 1.7804 - val_accuracy: 0.4332
# Epoch 59/200
# 50/50 [==============================] - 82s 2s/step - loss: 1.9162 - accuracy: 0.3682 - val_loss: 1.8984 - val_accuracy: 0.3650
# Epoch 60/200
# 50/50 [==============================] - 82s 2s/step - loss: 1.8559 - accuracy: 0.3866 - val_loss: 1.8461 - val_accuracy: 0.3709
# Epoch 61/200
# 50/50 [==============================] - 82s 2s/step - loss: 1.8456 - accuracy: 0.3777 - val_loss: 1.8447 - val_accuracy: 0.3769
# Epoch 62/200
# 50/50 [==============================] - 82s 2s/step - loss: 1.7651 - accuracy: 0.4096 - val_loss: 1.8304 - val_accuracy: 0.3947
# Epoch 63/200
# 50/50 [==============================] - 82s 2s/step - loss: 1
200
# 50/50 [==============================] - 82s 2s/step - loss: 1.4094 - accuracy: 0.5331 - val_loss: 1.4094 - val_accuracy: 0.5193
# Epoch 122/200
# 50/50 [==============================] - 81s 2s/step - loss: 1.4313 - accuracy: 0.5274 - val_loss: 1.6275 - val_accuracy: 0.5074
# Epoch 123/200
# 50/50 [==============================] - 82s 2s/step - loss: 1.3878 - accuracy: 0.5452 - val_loss: 1.7251 - val_accuracy: 0.4896
# Epoch 124/200
# 50/50 [==============================] - 82s 2s/step - loss: 1.4511 - accuracy: 0.5261 - val_loss: 1.5240 - val_accuracy: 0.5312
# Epoch 125/200
# 50/50 [==============================] - 82s 2s/step - loss: 1.4017 - accuracy: 0.5446 - val_loss: 1.6348 - val_accuracy: 0.5074
# Epoch 126/200
# 50/50 [==============================] - 81s 2s/step - loss: 1.3981 - accuracy: 0.5376 - val_loss: 1.6013 - val_accuracy: 0.4748
# Epoch 127/200
# 50/50 [==============================] - 82s 2s/step - loss: 1.4107 - accuracy: 0.5255 - val_loss: 1.5601 - val_accuracy: 0.5163
# Epoch 128/200
# 50/50 [==============================] - 82s 2s/step - loss: 1.3726 - accuracy: 0.5535 - val_loss: 1.4147 - val_accuracy: 0.5163
# Epoch 129/200
# 50/50 [==============================] - 81s 2s/step - loss: 1.4589 - accuracy: 0.5197 - val_loss: 1.4600 - val_accuracy: 0.4926
# Epoch 130/200
# 50/50 [==============================] - 82s 2s/step - loss: 1.3886 - accuracy: 0.5478 - val_loss: 1.4937 - val_accuracy: 0.4955
# Epoch 131/200
# 50/50 [==============================] - 82s 2s/step - loss: 1.4030 - accuracy: 0.5401 - val_loss: 1.5833 - val_accuracy: 0.4659
# Epoch 132/200
# 50/50 [==============================] - 82s 2s/step - loss: 1.4179 - accuracy: 0.5567 - val_loss: 1.4984 - val_accuracy: 0.4866
# Epoch 133/200
# 50/50 [==============================] - 82s 2s/step - loss: 1.4435 - accuracy: 0.5350 - val_loss: 1.6525 - val_accuracy: 0.4481
# Epoch 134/200
# 50/50 [==============================] - 81s 2s/step - loss: 1.4048 - accuracy: 0.5210 - val_loss: 1.5489 - val_accuracy: 0.4866
# Epoch 135/200
# 50/50 [==============================] - 82s 2s/step - loss: 1.3750 - accuracy: 0.5522 - val_loss: 1.5301 - val_accuracy: 0.5104
# Epoch 136/200
# 50/50 [==============================] - 82s 2s/step - loss: 1.3577 - accuracy: 0.5484 - val_loss: 1.4396 - val_accuracy: 0.5282
# Epoch 137/200
# 50/50 [==============================] - 82s 2s/step - loss: 1.3547 - accuracy: 0.5401 - val_loss: 1.4759 - val_accuracy: 0.5163
# Epoch 138/200
# 50/50 [==============================] - 81s 2s/step - loss: 1.3499 - accuracy: 0.5548 - val_loss: 1.4509 - val_accuracy: 0.5282
# Epoch 139/200
# 50/50 [==============================] - 81s 2s/step - loss: 1.3701 - accuracy: 0.5395 - val_loss: 1.5813 - val_accuracy: 0.4748
# Epoch 140/200
# 50/50 [==============================] - 82s 2s/step - loss: 1.3775 - accuracy: 0.5548 - val_loss: 1.6066 - val_accuracy: 0.5015
# Epoch 141/200
# 50/50 [==============================] - 82s 2s/step - loss: 1.3409 - accuracy: 0.5605 - val_loss: 1.6234 - val_accuracy: 0.4896
# Epoch 142/200
# 50/50 [==============================] - 86s 2s/step - loss: 1.3629 - accuracy: 0.5395 - val_loss: 1.5801 - val_accuracy: 0.5045
# Epoch 143/200
# 50/50 [==============================] - 86s 2s/step - loss: 1.2773 - accuracy: 0.5713 - val_loss: 1.5424 - val_accuracy: 0.5371
# Epoch 144/200
# 50/50 [==============================] - 86s 2s/step - loss: 1.3236 - accuracy: 0.5643 - val_loss: 1.5667 - val_accuracy: 0.5134
# Epoch 145/200
# 50/50 [==============================] - 85s 2s/step - loss: 1.3778 - accuracy: 0.5541 - val_loss: 1.5517 - val_accuracy: 0.5163
# Epoch 146/200
# 50/50 [==============================] - 85s 2s/step - loss: 1.2975 - accuracy: 0.5828 - val_loss: 1.3846 - val_accuracy: 0.5579
# Epoch 147/200
# 50/50 [==============================] - 82s 2s/step - loss: 1.2653 - accuracy: 0.5854 - val_loss: 1.5672 - val_accuracy: 0.5312
# Epoch 148/200
# 50/50 [==============================] - 82s 2s/step - loss: 1.3477 - accuracy: 0.5713 - val_loss: 1.3920 - val_accuracy: 0.5223
# Epoch 149/200
# 50/50 [==============================] - 82s 2s/step - loss: 1.3260 - accuracy: 0.5369 - val_loss: 1.4716 - val_accuracy: 0.5430
# Epoch 150/200
# 50/50 [==============================] - 83s 2s/step - loss: 1.3349 - accuracy: 0.5624 - val_loss: 1.5878 - val_accuracy: 0.5193
# Epoch 151/200
# 50/50 [==============================] - 83s 2s/step - loss: 1.3150 - accuracy: 0.5662 - val_loss: 1.5346 - val_accuracy: 0.5134
# Epoch 152/200
# 50/50 [==============================] - 82s 2s/step - loss: 1.3294 - accuracy: 0.5522 - val_loss: 1.4882 - val_accuracy: 0.5341
# Epoch 153/200
# 50/50 [==============================] - 82s 2s/step - loss: 1.3008 - accuracy: 0.5624 - val_loss: 1.6352 - val_accuracy: 0.5134
# Epoch 154/200
# 50/50 [==============================] - 84s 2s/step - loss: 1.2738 - accuracy: 0.5726 - val_loss: 1.5332 - val_accuracy: 0.4926
# Epoch 155/200
# 50/50 [==============================] - 83s 2s/step - loss: 1.3450 - accuracy: 0.5611 - val_loss: 1.6251 - val_accuracy: 0.5282
# Epoch 156/200
# 50/50 [==============================] - 82s 2s/step - loss: 1.2897 - accuracy: 0.5854 - val_loss: 1.4915 - val_accuracy: 0.5460
# Epoch 157/200
# 50/50 [==============================] - 82s 2s/step - loss: 1.3383 - accuracy: 0.5656 - val_loss: 1.6968 - val_accuracy: 0.5045
# Epoch 158/200
# 50/50 [==============================] - 82s 2s/step - loss: 1.3302 - accuracy: 0.5822 - val_loss: 1.4612 - val_accuracy: 0.5430
# Epoch 159/200
# 50/50 [==============================] - 82s 2s/step - loss: 1.3469 - accuracy: 0.5541 - val_loss: 1.4477 - val_accuracy: 0.5282
# Epoch 160/200
# 50/50 [==============================] - 82s 2s/step - loss: 1.2066 - accuracy: 0.5898 - val_loss: 1.5397 - val_accuracy: 0.5163
# Epoch 161/200
# 50/50 [==============================] - 82s 2s/step - loss: 1.2852 - accuracy: 0.5739 - val_loss: 1.5312 - val_accuracy: 0.5134
# Epoch 162/200
# 50/50 [==============================] - 82s 2s/step - loss: 1.2847 - accuracy: 0.5745 - val_loss: 1.6021 - val_accuracy: 0.5341
# Epoch 163/200
# 50/50 [==============================] - 82s 2s/step - loss: 1.2432 - accuracy: 0.5911 - val_loss: 1.3664 - val_accuracy: 0.5697
# Epoch 164/200
# 50/50 [==============================] - 82s 2s/step - loss: 1.3072 - accuracy: 0.5764 - val_loss: 1.4628 - val_accuracy: 0.5638
# Epoch 165/200
# 50/50 [==============================] - 82s 2s/step - loss: 1.2937 - accuracy: 0.5707 - val_loss: 1.6112 - val_accuracy: 0.5371
# Epoch 166/200
# 50/50 [==============================] - 85s 2s/step - loss: 1.3203 - accuracy: 0.5707 - val_loss: 1.4506 - val_accuracy: 0.5460
# Epoch 167/200
# 50/50 [==============================] - 87s 2s/step - loss: 1.2516 - accuracy: 0.6019 - val_loss: 1.4806 - val_accuracy: 0.5371
# Epoch 168/200
# 50/50 [==============================] - 87s 2s/step - loss: 1.2837 - accuracy: 0.5682 - val_loss: 1.7571 - val_accuracy: 0.4866
# Epoch 169/200
# 50/50 [==============================] - 87s 2s/step - loss: 1.3188 - accuracy: 0.5592 - val_loss: 1.7245 - val_accuracy: 0.5104
# Epoch 170/200
# 50/50 [==============================] - 86s 2s/step - loss: 1.2276 - accuracy: 0.5815 - val_loss: 1.5744 - val_accuracy: 0.5193
# Epoch 171/200
# 50/50 [==============================] - 86s 2s/step - loss: 1.3005 - accuracy: 0.5822 - val_loss: 1.4369 - val_accuracy: 0.5549
# Epoch 172/200
# 50/50 [==============================] - 87s 2s/step - loss: 1.2844 - accuracy: 0.5694 - val_loss: 1.5418 - val_accuracy: 0.5045
# Epoch 173/200
# 50/50 [==============================] - 88s 2s/step - loss: 1.2535 - accuracy: 0.5758 - val_loss: 1.4674 - val_accuracy: 0.5549
# Epoch 174/200
# 50/50 [==============================] - 87s 2s/step - loss: 1.3252 - accuracy: 0.5739 - val_loss: 1.4184 - val_accuracy: 0.5638
# Epoch 175/200
# 50/50 [==============================] - 87s 2s/step - loss: 1.2550 - accuracy: 0.6051 - val_loss: 1.5676 - val_accuracy: 0.5312
# Epoch 176/200
# 50/50 [==============================] - 87s 2s/step - loss: 1.3479 - accuracy: 0.5656 - val_loss: 1.4094 - val_accuracy: 0.5371
# Epoch 177/200
# 50/50 [==============================] - 88s 2s/step - loss: 1.2527 - accuracy: 0.5879 - val_loss: 1.3903 - val_accuracy: 0.5430
# Epoch 178/200
# 50/50 [==============================] - 88s 2s/step - loss: 1.2089 - accuracy: 0.6140 - val_loss: 1.3854 - val_accuracy: 0.5312
# Epoch 179/200
# 50/50 [==============================] - 89s 2s/step - loss: 1.2399 - accuracy: 0.5892 - val_loss: 1.2996 - val_accuracy: 0.5430
# Epoch 180/200
# 50/50 [==============================] - 87s 2s/step - loss: 1.2065 - accuracy: 0.5987 - val_loss: 1.3639 - val_accuracy: 0.5371
# Epoch 181/200
# 50/50 [==============================] - 87s 2s/step - loss: 1.2459 - accuracy: 0.5987 - val_loss: 1.5025 - val_accuracy: 0.5104
# Epoch 182/200
# 50/50 [==============================] - 88s 2s/step - loss: 1.2394 - accuracy: 0.5898 - val_loss: 1.5581 - val_accuracy: 0.5134
# Epoch 183/200
# 50/50 [==============================] - 88s 2s/step - loss: 1.2751 - accuracy: 0.5809 - val_loss: 1.4385 - val_accuracy: 0.5490
# Epoch 184/200
# 50/50 [==============================] - 88s 2s/step - loss: 1.2446 - accuracy: 0.5962 - val_loss: 1.3732 - val_accuracy: 0.5371
# Epoch 185/200
# 50/50 [==============================] - 88s 2s/step - loss: 1.2144 - accuracy: 0.5866 - val_loss: 1.5125 - val_accuracy: 0.5104
# Epoch 186/200
# 50/50 [==============================] - 88s 2s/step - loss: 1.2634 - accuracy: 0.5860 - val_loss: 1.3781 - val_accuracy: 0.5134
# Epoch 187/200
# 50/50 [==============================] - 88s 2s/step - loss: 1.2962 - accuracy: 0.5860 - val_loss: 1.4318 - val_accuracy: 0.5519
# Epoch 188/200
# 50/50 [==============================] - 88s 2s/step - loss: 1.1933 - accuracy: 0.6108 - val_loss: 1.4856 - val_accuracy: 0.5460
# Epoch 189/200
# 50/50 [==============================] - 88s 2s/step - loss: 1.2019 - accuracy: 0.6146 - val_loss: 1.3569 - val_accuracy: 0.5460
# Epoch 190/200
# 50/50 [==============================] - 88s 2s/step - loss: 1.1776 - accuracy: 0.6153 - val_loss: 1.3512 - val_accuracy: 0.5519
# Epoch 191/200
# 50/50 [==============================] - 87s 2s/step - loss: 1.2128 - accuracy: 0.6127 - val_loss: 1.4829 - val_accuracy: 0.5223
# Epoch 192/200
# 50/50 [==============================] - 87s 2s/step - loss: 1.2107 - accuracy: 0.5904 - val_loss: 1.3076 - val_accuracy: 0.5341
# Epoch 193/200
# 50/50 [==============================] - 88s 2s/step - loss: 1.1740 - accuracy: 0.6121 - val_loss: 1.3745 - val_accuracy: 0.5549
# Epoch 194/200
# 50/50 [==============================] - 87s 2s/step - loss: 1.1614 - accuracy: 0.6121 - val_loss: 1.3676 - val_accuracy: 0.5430
# Epoch 195/200
# 50/50 [==============================] - 88s 2s/step - loss: 1.1884 - accuracy: 0.6089 - val_loss: 1.3290 - val_accuracy: 0.5430
# Epoch 196/200
# 50/50 [==============================] - 87s 2s/step - loss: 1.1239 - accuracy: 0.6159 - val_loss: 1.3345 - val_accuracy: 0.5816
# Epoch 197/200
# 50/50 [==============================] - 88s 2s/step - loss: 1.2243 - accuracy: 0.5917 - val_loss: 1.3956 - val_accuracy: 0.5519
# Epoch 198/200
# 50/50 [==============================] - 88s 2s/step - loss: 1.1689 - accuracy: 0.6057 - val_loss: 1.4502 - val_accuracy: 0.5193
# Epoch 199/200
# 50/50 [==============================] - 88s 2s/step - loss: 1.1840 - accuracy: 0.6204 - val_loss: 1.4479 - val_accuracy: 0.5282
# Epoch 200/200
# 50/50 [==============================] - 87s 2s/step - loss: 1.1879 - accuracy: 0.6006 - val_loss: 1.5090 - val_accuracy: 0.5401

# %%
print("Accuracy of the model on train data is {:.2f}%".format(history.history["accuracy"][-1]*100))
# Out:
# Accuracy of the model on train data is 60.06%

# %%
import matplotlib.pyplot as plt
acc=history.history['accuracy']
val_acc=history.history['val_accuracy']
loss=history.history['loss']
val_loss=history.history['val_loss']

epochs=range(len(acc))

fig = plt.figure(figsize=(14,7))
plt.plot(epochs, acc, 'r', label="Training Accuracy")
plt.plot(epochs, val_acc, 'b', label="Validation Accuracy")
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and validation accuracy')
plt.legend(loc='lower right')
plt.show()

# %%
fig2 = plt.figure(figsize=(14,7))
plt.plot(epochs, loss, 'r', label="Training Loss")
plt.plot(epochs, val_loss, 'b', label="Validation Loss")
plt.legend(loc='upper right')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and validation loss')
# Out:
# Text(0.5, 1.0, 'Training and validation loss')

# %% [markdown]
# Save Model

# %%
# model.save('/content/drive/MyDrive/indosnake/model/snake_model.h5')

# %%
modelku = '/content/drive/MyDrive/Colab Notebooks/indosnake/snake_model.tflite'
tf_lite_converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = tf_lite_converter.convert()

tflite_model_name = modelku
open(tflite_model_name, "wb").write(tflite_model)
# Out:
# WARNING:absl:Found untraced functions such as dropout_layer_call_and_return_conditional_losses, dropout_layer_call_fn, dropout_1_layer_call_and_return_conditional_losses, dropout_1_layer_call_fn, dropout_2_layer_call_and_return_conditional_losses while saving (showing 5 of 30). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /tmp/tmpvlrajhx5/assets
# INFO:tensorflow:Assets written to: /tmp/tmpvlrajhx5/assets
# 5077912

# %%
valid = '/content/drive/MyDrive/Indo_snake/Single Pred/'
test_img = os.listdir(os.path.join(valid))

test_df = pd.DataFrame({'Image': test_img})
test_df.head()
# Out:
#                         Image
# 0  Calamaria schlegeli 1.jpeg
# 1  Calamaria schlegeli 2.jpeg
# 2   Calamaria schlegeli 3.JPG
# 3     Boiga Dendrophila 1.jpg
# 4     Boiga Dendrophila 2.jpg

# %%
valid_gen = ImageDataGenerator(rescale=1./255)

valid_generator = valid_gen.flow_from_dataframe(
    test_df, 
    valid, 
    x_col = 'Image',
    y_col = None,
    class_mode = None,
    target_size = (150, 200),
    batch_size = 1,
    shuffle = False
)
# Out:
# Found 51 validated image filenames.

# %%
predict = model.predict_generator(valid_generator, steps = 51)
predict
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:2001: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   warnings.warn('`Model.predict_generator` is deprecated and '
# array([[1.52080262e-04, 2.08065938e-03, 6.30329072e-04, 4.75676432e-02,
#         8.03352520e-02, 2.77120452e-02, 3.78801525e-02, 5.45365959e-02,
#         6.68403786e-03, 4.20005817e-05, 2.99771992e-03, 2.58441661e-02,
#         6.20626546e-02, 3.59697379e-02, 5.92433095e-01, 2.30646376e-02,
#         7.21862580e-06],
#        [5.81604108e-05, 1.01432940e-02, 1.82277436e-04, 1.62591841e-02,
#         1.10408917e-01, 8.32418562e-04, 1.52227310e-02, 2.00274512e-01,
#         1.45364985e-01, 3.83897941e-06, 4.75886092e-03, 2.03496851e-02,
#         1.37113929e-02, 8.26888811e-03, 4.46842432e-01, 7.31032481e-03,
#         8.13441511e-06],
#        [7.53233107e-05, 4.03869955e-04, 7.82050658e-04, 3.69257808e-01,
#         4.91436124e-01, 5.41625731e-02, 8.59705079e-03, 1.24546586e-05,
#         6.73599425e-05, 1.05547348e-04, 3.28322960e-04, 1.84845459e-03,
#         3.46197747e-03, 1.96998846e-03, 8.75978847e-04, 6.66014180e-02,
#         1.37525776e-05],
#        [9.65828300e-01, 4.85256361e-03, 2.45955065e-02, 6.67867880e-07,
#         1.56977858e-05, 1.50010828e-06, 6.82068057e-05, 1.33522633e-07,
#         2.64318452e-08, 2.04962504e-04, 2.57371744e-06, 3.20722756e-04,
#         4.23224701e-05, 1.58311019e-03, 1.46974308e-08, 2.48138909e-03,
#         2.29406805e-06],
#        [9.97249901e-01, 2.81972206e-08, 2.74980674e-03, 9.03804653e-15,
#         2.29672965e-11, 8.82047582e-13, 3.95812758e-11, 2.78039723e-17,
#         6.07528260e-18, 2.65649849e-08, 1.47858364e-12, 8.59355538e-08,
#         3.36883910e-10, 3.88157595e-08, 2.41688464e-18, 3.32359207e-08,
#         1.27034410e-13],
#        [1.00000000e+00, 9.98916675e-17, 2.82769034e-13, 5.20085255e-38,
#         2.47729077e-30, 3.04280947e-38, 4.21727043e-26, 0.00000000e+00,
#         0.00000000e+00, 3.95782276e-23, 2.65017555e-35, 2.71451830e-24,
#         9.33733785e-28, 5.44220943e-19, 0.00000000e+00, 3.14233011e-18,
#         4.82377735e-33],
#        [6.43775365e-06, 7.27762580e-01, 4.99071041e-03, 2.91572042e-06,
#        [7.33171701e-09, 2.07425330e-07, 1.45407131e-10, 1.68033818e-08,
#         1.10797146e-07, 2.79745677e-07, 2.27770840e-11, 1.01968521e-06,
#         2.42116803e-05, 1.86686739e-01, 2.51705434e-09, 2.10881581e-07,
#         4.59655930e-05, 3.49004438e-07, 1.12175309e-08, 9.56248858e-09,
#         8.13240886e-01],
#        [5.24748793e-06, 3.83512815e-05, 1.32460832e-06, 8.02863360e-05,
#         2.26673201e-05, 7.93495656e-06, 4.02895603e-06, 5.43203612e-04,
#         5.28180040e-03, 3.99668455e-01, 1.58101534e-06, 3.55645011e-06,
#         5.30756428e-04, 8.68471630e-04, 3.57469180e-05, 7.38209637e-05,
#         5.92832804e-01],
#        [1.22011363e-06, 7.47859813e-05, 1.06873244e-07, 7.75408698e-05,
#         1.61562057e-04, 1.46590164e-05, 2.10000644e-06, 5.22333605e-04,
#         3.33663309e-03, 2.38354415e-01, 7.92805906e-07, 1.70176390e-05,
#         7.92971172e-04, 2.22815754e-04, 3.75818240e-06, 6.71390308e-06,
#         7.56410599e-01]], dtype=float32)

# %%
# Identifying the classes

label_map = dict((v,k) for k,v in train_generator.class_indices.items())
label_map
# Out:
# {0: 'Boiga Dendrophila  (Ular Cincin Emas)',
#  1: 'Bungarus Candidus (Ular Weling)',
#  2: 'Bungarus Fasciatus (Ular Welang)',
#  3: 'Bungarus Flaviceps (Krait Kepala Merah)',
#  4: 'Calamaria Schlegeli (Ular Buluh Berkepala Merah)',
#  5: 'Calliophis Bivirgatus (Ular Cabai Besar)',
#  6: 'Calliophis Intestinalis (Ular Cabai Kecil)',
#  7: 'Calloselasma Rhodostoma (Ular Tanah)',
#  8: 'Daboia Siamensis (Ular Bandotan Puspa)',
#  9: 'Gonyosoma Oxycephalum (Ular Bajing)',
#  10: 'Hydrophis Belcheri (Ular Laut Belcher )',
#  11: 'Lycodon Subcinctus (Ular Cicak)',
#  12: 'Naja sumatrana (Ular Kobra Sumatra)',
#  13: 'Ophiophagus Hannah (King Cobra)',
#  14: 'Oxyuranus Scutellatus (Ular Taipan Pesisir)',
#  15: 'Rhabdophis Subminiatus (Ular Picung)',
#  16: 'Trimeresurus Albolabris (Ular Bangkai Laut)'}

# %%
test_df['Label'] = np.argmax(predict, axis = -1)
test_df['Label']
# Out:
# 0     14
# 1     14
# 2      4
# 3      0
# 4      0
# 5      0
# 6      1
# 7     10
# 8      1
# 9     13
# 10     2
# 11     2
# 12     3
# 13     6
# 14     3
# 15     5
# 16     5
# 17     5
# 18    14
# 19     7
# 20     6
# 21     8
# 22     8
# 23     8
# 24     8
# 25     8
# 26     8
# 27     9
# 28     9
# 29     3
# 30    12
# 31    10
# 32    10
# 33     1
# 34     8
# 35    11
# 36     8
# 37    13
# 38     7
# 39     8
# 40    13
# 41    14
# 42     8
# 43    14
# 44    14
# 45    12
# 46    12
# 47    15
# 48    16
# 49    16
# 50    16
# Name: Label, dtype: int64

# %%
actual_df = pd.read_csv('/content/drive/MyDrive/Indo_snake/test.csv')
y_true = actual_df['labels']
y_pred = test_df['Label']
print(y_true)
# Out:
# 0      0
# 1      0
# 2      0
# 3      1
# 4      1
# 5      1
# 6      2
# 7      2
# 8      2
# 9      3
# 10     3
# 11     3
# 12     4
# 13     4
# 14     4
# 15     5
# 16     5
# 17     5
# 18     6
# 19     6
# 20     6
# 21     7
# 22     7
# 23     7
# 24     8
# 25     8
# 26     8
# 27     9
# 28     9
# 29     9
# 30    10
# 31    10
# 32    10
# 33    11
# 34    11
# 35    11
# 36    12
# 37    12
# 38    12
# 39    13
# 40    13
# 41    13
# 42    14
# 43    14
# 44    14
# 45    15
# 46    15
# 47    15
# 48    16
# 49    16
# 50    16
# Name: labels, dtype: int64

# %%
from sklearn.metrics import confusion_matrix
from mlxtend.plotting import plot_confusion_matrix
cm = confusion_matrix(y_true,y_pred)
plot_confusion_matrix(conf_mat = cm,figsize=(8,7));

# %%
v = random.randint(0, 12)

sample_test = test_df.iloc[v:(v+18)].reset_index(drop = True)
sample_test.head()

plt.figure(figsize=(12, 24))
for index, row in sample_test.iterrows():
    filename = row['Image']
    category = row['Label']
    img = load_img(valid + filename, target_size = (150, 200))
    plt.subplot(6, 3, index + 1)
    plt.imshow(img)
    plt.xlabel(filename + ' ( ' + "{}".format(category) + ' )' )
plt.tight_layout()
plt.show()

# %%
test_df['Label'] = test_df['Label'].replace(label_map)
test_df
# Out:
#                              Image                                             Label
# 0       Calamaria schlegeli 1.jpeg       Oxyuranus Scutellatus (Ular Taipan Pesisir)
# 1       Calamaria schlegeli 2.jpeg       Oxyuranus Scutellatus (Ular Taipan Pesisir)
# 2        Calamaria schlegeli 3.JPG  Calamaria Schlegeli (Ular Buluh Berkepala Merah)
# 3          Boiga Dendrophila 1.jpg             Boiga Dendrophila  (Ular Cincin Emas)
# 4          Boiga Dendrophila 2.jpg             Boiga Dendrophila  (Ular Cincin Emas)
# 5          Boiga Dendrophila 3.jpg             Boiga Dendrophila  (Ular Cincin Emas)
# 6         Bungarus Candidus 1.jpeg                   Bungarus Candidus (Ular Weling)
# 7         Bungarus Candidus 2.jpeg           Hydrophis Belcheri (Ular Laut Belcher )
# 8         Bungarus Candidus 3.jpeg                   Bungarus Candidus (Ular Weling)
# 9        Bungarus Fasciatus 1.jpeg                   Ophiophagus Hannah (King Cobra)
# 10       Bungarus Fasciatus 2.jpeg                  Bungarus Fasciatus (Ular Welang)
# 11        Bungarus Fasciatus 3.jpg                  Bungarus Fasciatus (Ular Welang)
# 12        Bungarus Flaviceps 1.jpg           Bungarus Flaviceps (Krait Kepala Merah)
# 13       Bungarus Flaviceps 2.jpeg        Calliophis Intestinalis (Ular Cabai Kecil)
# 14        Bungarus Flaviceps 3.JPG           Bungarus Flaviceps (Krait Kepala Merah)
# 15    Calliophis Bivirgatus 1.jpeg          Calliophis Bivirgatus (Ular Cabai Besar)
# 16    Calliophis Bivirgatus 2.jpeg          Calliophis Bivirgatus (Ular Cabai Besar)
# 17     Calliophis Bivirgatus 3.JPG          Calliophis Bivirgatus (Ular Cabai Besar)
# 18   Calliophis Intestinalis 1.JPG       Oxyuranus Scutellatus (Ular Taipan Pesisir)
