# %% [markdown]
# <a href="https://colab.research.google.com/github/icahlatif/My_List/blob/master/Copy_of_42618021_UAS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

import os
import random
import shutil

import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img

import matplotlib.pyplot as plt

# %%
train_dir = "/content/drive/MyDrive/Indo_snake/Training/"
test_dir = "/content/drive/MyDrive/Indo_snake/Testing/"

# %%
# Displaying random image from the dataset
fig, ax = plt.subplots(4, 5, figsize=(15, 10))

sample_paper = random.choice(os.listdir(train_dir + "Boiga Dendrophila  (Ular Cincin Emas)"))
image = load_img(train_dir + "Boiga Dendrophila  (Ular Cincin Emas)/" + sample_paper)
ax[0, 0].imshow(image)
ax[0, 0].set_title("Ular Cincin")


sample_paper = random.choice(os.listdir(train_dir + "Bungarus Candidus (Ular Weling)"))
image = load_img(train_dir + "Bungarus Candidus (Ular Weling)/" + sample_paper)
ax[0, 1].imshow(image)
ax[0, 1].set_title("Ular Weling")

sample_paper = random.choice(os.listdir(train_dir + "Bungarus Fasciatus (Ular Welang)"))
image = load_img(train_dir + "Bungarus Fasciatus (Ular Welang)/" + sample_paper)
ax[0, 2].imshow(image)
ax[0, 2].set_title("Ular Welang")


sample_paper = random.choice(os.listdir(train_dir + "Bungarus Flaviceps (Krait Kepala Merah)"))
image = load_img(train_dir + "Bungarus Flaviceps (Krait Kepala Merah)/" + sample_paper)
ax[0, 3].imshow(image)
ax[0, 3].set_title("Ular Krait")


sample_paper = random.choice(os.listdir(train_dir + "Calamaria Schlegeli (Ular Buluh Berkepala Merah)"))
image = load_img(train_dir + "Calamaria Schlegeli (Ular Buluh Berkepala Merah)/" + sample_paper)
ax[0, 4].imshow(image)
ax[0, 4].set_title("Ular Calamaria")


sample_paper = random.choice(os.listdir(train_dir + "Calliophis Bivirgatus (Ular Cabai Besar)"))
image = load_img(train_dir + "Calliophis Bivirgatus (Ular Cabai Besar)/" + sample_paper)
ax[1, 0].imshow(image)
ax[1, 0].set_title("Ular Cabai Besar")
ax[1, 0].axis("Off")

sample_paper = random.choice(os.listdir(train_dir + "Calliophis Intestinalis (Ular Cabai Kecil)"))
image = load_img(train_dir + "Calliophis Intestinalis (Ular Cabai Kecil)/" + sample_paper)
ax[1, 1].imshow(image)
ax[1, 1].set_title("Ular Cabai Kecil")
ax[1, 1].axis("Off")

sample_paper = random.choice(os.listdir(train_dir + "Calloselasma Rhodostoma (Ular Tanah)"))
image = load_img(train_dir + "Calloselasma Rhodostoma (Ular Tanah)/" + sample_paper)
ax[1, 2].imshow(image)
ax[1, 2].set_title("Ular Tanah")
ax[1, 2].axis("Off")

sample_paper = random.choice(os.listdir(train_dir + "Daboia Siamensis (Ular Bandotan Puspa)"))
image = load_img(train_dir + "Daboia Siamensis (Ular Bandotan Puspa)/" + sample_paper)
ax[1, 3].imshow(image)
ax[1, 3].set_title("Ular Bandotan Puspa")
ax[1, 3].axis("Off")

sample_paper = random.choice(os.listdir(train_dir + "Gonyosoma Oxycephalum (Ular Bajing)"))
image = load_img(train_dir + "Gonyosoma Oxycephalum (Ular Bajing)/" + sample_paper)
ax[1, 4].imshow(image)
ax[1, 4].set_title("Ular Bajing")
ax[1, 4].axis("Off")

sample_paper = random.choice(os.listdir(train_dir + "Hydrophis Belcheri (Ular Laut Belcher )"))
image = load_img(train_dir + "Hydrophis Belcheri (Ular Laut Belcher )/" + sample_paper)
ax[2, 0].imshow(image)
ax[2, 0].set_title("Ular Belcher")
ax[2, 0].axis("Off")

sample_paper = random.choice(os.listdir(train_dir + "Lycodon Subcinctus (Ular Cicak)"))
image = load_img(train_dir + "Lycodon Subcinctus (Ular Cicak)/" + sample_paper)
ax[2, 1].imshow(image)
ax[2, 1].set_title("Ular Cicak")
ax[2, 1].axis("Off")

sample_paper = random.choice(os.listdir(train_dir + "Naja sumatrana (Ular Kobra Sumatra)"))
image = load_img(train_dir + "Naja sumatrana (Ular Kobra Sumatra)/" + sample_paper)
ax[2, 2].imshow(image)
ax[2, 2].set_title("Ular Kobra Sumatra")
ax[2, 2].axis("Off")

sample_paper = random.choice(os.listdir(train_dir + "Ophiophagus Hannah (King Cobra)"))
image = load_img(train_dir + "Ophiophagus Hannah (King Cobra)/" + sample_paper)
ax[2, 3].imshow(image)
ax[2, 3].set_title("King Cobra")
ax[2, 3].axis("Off")

sample_paper = random.choice(os.listdir(train_dir + "Oxyuranus Scutellatus (Ular Taipan Pesisir)"))
image = load_img(train_dir + "Oxyuranus Scutellatus (Ular Taipan Pesisir)/" + sample_paper)
ax[2, 4].imshow(image)
ax[2, 4].set_title("Ular Taipan Pesisir")
ax[2, 4].axis("Off")

ax[3, 0].axis("Off")
sample_paper = random.choice(os.listdir(train_dir + "Rhabdophis Subminiatus (Ular Picung)"))
image = load_img(train_dir + "Rhabdophis Subminiatus (Ular Picung)/" + sample_paper)
ax[3, 1].imshow(image)
ax[3, 1].set_title("Ular Picung")
ax[3, 1].axis("Off")
ax[3, 2].axis("Off")
sample_paper = random.choice(os.listdir(train_dir + "Trimeresurus Albolabris (Ular Bangkai Laut)"))
image = load_img(train_dir + "Trimeresurus Albolabris (Ular Bangkai Laut)/" + sample_paper)
ax[3, 3].imshow(image)
ax[3, 3].set_title("Ular Bangkai Laut")
ax[3, 3].axis("Off")
ax[3, 4].axis("Off")
# Out:
# (0.0, 1.0, 0.0, 1.0)

# %%
train_datagen = ImageDataGenerator(
      rescale=1./255,
      rotation_range=30,
      width_shift_range=0.4, # Shifting image width by 40%
      height_shift_range=0.4,# Shifting image height by 40%
      shear_range=0.2,       # Rotation across X-axis by 20%
      zoom_range=0.3,        # Image zooming by 30%
      vertical_flip = True,
      horizontal_flip=True)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size = (150, 200),
    class_mode = 'categorical',
    batch_size = 32
)

test_datagen = ImageDataGenerator(
      rescale=1./255)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size = (150, 200),
    class_mode = 'categorical',
    batch_size = 32
)
# Out:
# Found 1570 images belonging to 17 classes.
# Found 337 images belonging to 17 classes.

# %%
from keras.layers import Dense, Dropout, Flatten
model = tf.keras.models.Sequential([
    
    tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(150, 200, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),
    Dropout(0.25),

    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    Dropout(0.25),
    
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    Dropout(0.25),
    
    tf.keras.layers.Flatten(),
    
    tf.keras.layers.Dense(32, activation='relu'),
    Dropout(0.25),
    tf.keras.layers.Dense(17, activation='softmax')
])
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_5 (Conv2D)            (None, 148, 198, 32)      896
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 74, 99, 32)        0
# _________________________________________________________________
# module_wrapper_7 (ModuleWrap (None, 74, 99, 32)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 72, 97, 32)        9248
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 36, 48, 32)        0
# _________________________________________________________________
# module_wrapper_8 (ModuleWrap (None, 36, 48, 32)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 34, 46, 64)        18496
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 17, 23, 64)        0
# _________________________________________________________________
# module_wrapper_9 (ModuleWrap (None, 17, 23, 64)        0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 25024)             0
# _________________________________________________________________
# dense_4 (Dense)              (None, 32)                800800
# _________________________________________________________________
# module_wrapper_10 (ModuleWra (None, 32)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 17)                561
# =================================================================
# Total params: 830,001
# Trainable params: 830,001
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss = 'categorical_crossentropy',
              optimizer = 'adam',
              metrics = ['accuracy'])

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=30)

# %%
history = model.fit_generator(train_generator,
                              epochs=200,
                              verbose=1,
                              validation_data=test_generator,
                              callbacks = [es])
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1940: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/200
# 50/50 [==============================] - 444s 9s/step - loss: 2.8645 - accuracy: 0.0497 - val_loss: 2.8329 - val_accuracy: 0.0386
# Epoch 2/200
# 50/50 [==============================] - 81s 2s/step - loss: 2.8320 - accuracy: 0.0726 - val_loss: 2.8322 - val_accuracy: 0.0772
# Epoch 3/200
# 50/50 [==============================] - 80s 2s/step - loss: 2.8243 - accuracy: 0.0809 - val_loss: 2.8144 - val_accuracy: 0.0742
# Epoch 4/200
# 50/50 [==============================] - 81s 2s/step - loss: 2.7843 - accuracy: 0.0898 - val_loss: 2.7415 - val_accuracy: 0.1009
# Epoch 5/200
# 50/50 [==============================] - 80s 2s/step - loss: 2.7462 - accuracy: 0.1159 - val_loss: 2.7075 - val_accuracy: 0.1187
# Epoch 6/200
# 50/50 [==============================] - 80s 2s/step - loss: 2.7501 - accuracy: 0.1217 - val_loss: 2.6907 - val_accuracy: 0.1513
# Epoch 7/200
# 50/50 [==============================] - 80s 2s/step - loss: 2.7086 - accuracy: 0.1306 - val_loss: 2.6397 - val_accuracy: 0.1365
# Epoch 8/200
# 50/50 [==============================] - 80s 2s/step - loss: 2.6806 - accuracy: 0.1331 - val_loss: 2.6820 - val_accuracy: 0.1662
# Epoch 9/200
# 50/50 [==============================] - 80s 2s/step - loss: 2.6849 - accuracy: 0.1408 - val_loss: 2.5896 - val_accuracy: 0.1424
# Epoch 10/200
# 50/50 [==============================] - 79s 2s/step - loss: 2.6160 - accuracy: 0.1395 - val_loss: 2.5397 - val_accuracy: 0.1780
# Epoch 11/200
# 50/50 [==============================] - 80s 2s/step - loss: 2.6294 - accuracy: 0.1287 - val_loss: 2.5243 - val_accuracy: 0.1899
# Epoch 12/200
# 50/50 [==============================] - 80s 2s/step - loss: 2.6162 - accuracy: 0.1529 - val_loss: 2.5076 - val_accuracy: 0.1869
# Epoch 13/200
# 50/50 [==============================] - 80s 2s/step - loss: 2.6082 - accuracy: 0.1408 - val_loss: 2.5530 - val_accuracy: 0.1840
# Epoch 14/200
# 50/50 [==============================] - 79s 2s/step - loss: 2.5779 - accuracy: 0.1484 - val_loss: 2.4743 - val_accuracy: 0.1958
# Epoch 15/200
# 50/50 [==============================] - 80s 2s/step - loss: 2.5564 - accuracy: 0.1548 - val_loss: 2.4383 - val_accuracy: 0.2166
# Epoch 16/200
# 50/50 [==============================] - 81s 2s/step - loss: 2.5017 - accuracy: 0.1732 - val_loss: 2.4037 - val_accuracy: 0.2077
# Epoch 17/200
# 50/50 [==============================] - 80s 2s/step - loss: 2.5119 - accuracy: 0.1682 - val_loss: 2.4281 - val_accuracy: 0.1929
# Epoch 18/200
# 50/50 [==============================] - 79s 2s/step - loss: 2.4914 - accuracy: 0.1834 - val_loss: 2.3515 - val_accuracy: 0.2285
# Epoch 19/200
# 50/50 [==============================] - 80s 2s/step - loss: 2.4615 - accuracy: 0.1917 - val_loss: 2.2948 - val_accuracy: 0.2136
# Epoch 20/200
# 50/50 [==============================] - 80s 2s/step - loss: 2.4645 - accuracy: 0.1815 - val_loss: 2.3433 - val_accuracy: 0.2255
# Epoch 21/200
# 50/50 [==============================] - 80s 2s/step - loss: 2.4505 - accuracy: 0.1764 - val_loss: 2.3873 - val_accuracy: 0.2107
# Epoch 22/200
# 50/50 [==============================] - 80s 2s/step - loss: 2.4056 - accuracy: 0.2000 - val_loss: 2.3142 - val_accuracy: 0.2226
# Epoch 23/200
# 50/50 [==============================] - 79s 2s/step - loss: 2.4343 - accuracy: 0.1943 - val_loss: 2.3233 - val_accuracy: 0.2255
# Epoch 24/200
# 50/50 [==============================] - 79s 2s/step - loss: 2.4413 - accuracy: 0.2000 - val_loss: 2.2482 - val_accuracy: 0.2404
# Epoch 25/200
# 50/50 [==============================] - 79s 2s/step - loss: 2.4346 - accuracy: 0.1873 - val_loss: 2.2655 - val_accuracy: 0.2493
# Epoch 26/200
# 50/50 [==============================] - 79s 2s/step - loss: 2.3870 - accuracy: 0.2013 - val_loss: 2.4326 - val_accuracy: 0.2344
# Epoch 27/200
# 50/50 [==============================] - 79s 2s/step - loss: 2.3944 - accuracy: 0.2000 - val_loss: 2.2864 - val_accuracy: 0.2463
# Epoch 28/200
# 50/50 [==============================] - 79s 2s/step - loss: 2.4168 - accuracy: 0.2025 - val_loss: 2.2730 - val_accuracy: 0.2374
# Epoch 29/200
# 50/50 [==============================] - 79s 2s/step - loss: 2.3745 - accuracy: 0.2070 - val_loss: 2.2413 - val_accuracy: 0.2522
# Epoch 30/200
# 50/50 [==============================] - 79s 2s/step - loss: 2.3925 - accuracy: 0.1994 - val_loss: 2.2290 - val_accuracy: 0.2463
# Epoch 31/200
# 50/50 [==============================] - 78s 2s/step - loss: 2.3350 - accuracy: 0.2210 - val_loss: 2.3027 - val_accuracy: 0.2611
# Epoch 32/200
# 50/50 [==============================] - 79s 2s/step - loss: 2.3380 - accuracy: 0.2204 - val_loss: 2.2327 - val_accuracy: 0.2819
# Epoch 33/200
# 50/50 [==============================] - 79s 2s/step - loss: 2.3955 - accuracy: 0.2070 - val_loss: 2.2365 - val_accuracy: 0.2671
# Epoch 34/200
# 50/50 [==============================] - 79s 2s/step - loss: 2.3616 - accuracy: 0.2166 - val_loss: 2.3494 - val_accuracy: 0.2552
# Epoch 35/200
# 50/50 [==============================] - 79s 2s/step - loss: 2.3636 - accuracy: 0.2108 - val_loss: 2.3122 - val_accuracy: 0.2522
# Epoch 36/200
# 50/50 [==============================] - 79s 2s/step - loss: 2.3234 - accuracy: 0.2108 - val_loss: 2.2228 - val_accuracy: 0.2582
# Epoch 37/200
# 50/50 [==============================] - 79s 2s/step - loss: 2.3304 - accuracy: 0.2127 - val_loss: 2.3055 - val_accuracy: 0.2700
# Epoch 38/200
# 50/50 [==============================] - 79s 2s/step - loss: 2.3407 - accuracy: 0.2127 - val_loss: 2.2458 - val_accuracy: 0.2641
# Epoch 39/200
# 50/50 [==============================] - 79s 2s/step - loss: 2.3140 - accuracy: 0.2191 - val_loss: 2.1951 - val_accuracy: 0.2463
# Epoch 40/200
# 50/50 [==============================] - 79s 2s/step - loss: 2.3433 - accuracy: 0.2255 - val_loss: 2.3406 - val_accuracy: 0.2641
# Epoch 41/200
# 50/50 [==============================] - 79s 2s/step - loss: 2.3270 - accuracy: 0.2089 - val_loss: 2.2639 - val_accuracy: 0.2582
# Epoch 42/200
# 50/50 [==============================] - 79s 2s/step - loss: 2.2916 - accuracy: 0.2280 - val_loss: 2.2756 - val_accuracy: 0.2789
# Epoch 43/200
# 50/50 [==============================] - 79s 2s/step - loss: 2.3090 - accuracy: 0.2178 - val_loss: 2.1767 - val_accuracy: 0.2908
# Epoch 44/200
# 50/50 [==============================] - 79s 2s/step - loss: 2.3100 - accuracy: 0.2045 - val_loss: 2.2084 - val_accuracy: 0.2849
# Epoch 45/200
# 50/50 [==============================] - 79s 2s/step - loss: 2.2799 - accuracy: 0.2312 - val_loss: 2.2934 - val_accuracy: 0.2760
# Epoch 46/200
# 50/50 [==============================] - 79s 2s/step - loss: 2.2859 - accuracy: 0.2338 - val_loss: 2.2145 - val_accuracy: 0.2760
# Epoch 47/200
# 50/50 [==============================] - 79s 2s/step - loss: 2.2781 - accuracy: 0.2280 - val_loss: 2.1796 - val_accuracy: 0.2789
# Epoch 48/200
# 50/50 [==============================] - 78s 2s/step - loss: 2.4951 - accuracy: 0.1879 - val_loss: 2.3602 - val_accuracy: 0.2018
# Epoch 49/200
# 50/50 [==============================] - 79s 2s/step - loss: 2.3439 - accuracy: 0.2166 - val_loss: 2.1693 - val_accuracy: 0.2493
# Epoch 50/200
# 50/50 [==============================] - 78s 2s/step - loss: 2.2924 - accuracy: 0.2204 - val_loss: 2.1664 - val_accuracy: 0.2908
# Epoch 51/200
# 50/50 [==============================] - 78s 2s/step - loss: 2
200
# 50/50 [==============================] - 78s 2s/step - loss: 2.0667 - accuracy: 0.2975 - val_loss: 2.0588 - val_accuracy: 0.3116
# Epoch 82/200
# 50/50 [==============================] - 78s 2s/step - loss: 2.1039 - accuracy: 0.2987 - val_loss: 2.0481 - val_accuracy: 0.3294
# Epoch 83/200
# 50/50 [==============================] - 78s 2s/step - loss: 2.1146 - accuracy: 0.2720 - val_loss: 1.9893 - val_accuracy: 0.3591
# Epoch 84/200
# 50/50 [==============================] - 78s 2s/step - loss: 2.1035 - accuracy: 0.2828 - val_loss: 2.0108 - val_accuracy: 0.3323
# Epoch 85/200
# 50/50 [==============================] - 80s 2s/step - loss: 2.1183 - accuracy: 0.2943 - val_loss: 2.0202 - val_accuracy: 0.3086
# Epoch 86/200
# 50/50 [==============================] - 78s 2s/step - loss: 2.0926 - accuracy: 0.3000 - val_loss: 1.9352 - val_accuracy: 0.3739
# Epoch 87/200
# 50/50 [==============================] - 78s 2s/step - loss: 2.0387 - accuracy: 0.3166 - val_loss: 2.0020 - val_accuracy: 0.3353
# Epoch 88/200
# 50/50 [==============================] - 78s 2s/step - loss: 2.0129 - accuracy: 0.3210 - val_loss: 1.9717 - val_accuracy: 0.3442
# Epoch 89/200
# 50/50 [==============================] - 78s 2s/step - loss: 2.0326 - accuracy: 0.3274 - val_loss: 2.1033 - val_accuracy: 0.3353
# Epoch 90/200
# 50/50 [==============================] - 78s 2s/step - loss: 2.0062 - accuracy: 0.3217 - val_loss: 1.9150 - val_accuracy: 0.3739
# Epoch 91/200
# 50/50 [==============================] - 78s 2s/step - loss: 2.0496 - accuracy: 0.3045 - val_loss: 1.9761 - val_accuracy: 0.3383
# Epoch 92/200
# 50/50 [==============================] - 78s 2s/step - loss: 1.9984 - accuracy: 0.3159 - val_loss: 1.8838 - val_accuracy: 0.3769
# Epoch 93/200
# 50/50 [==============================] - 78s 2s/step - loss: 1.9980 - accuracy: 0.3401 - val_loss: 1.9320 - val_accuracy: 0.3531
# Epoch 94/200
# 50/50 [==============================] - 78s 2s/step - loss: 1.9593 - accuracy: 0.3420 - val_loss: 1.9750 - val_accuracy: 0.3709
# Epoch 95/200
# 50/50 [==============================] - 78s 2s/step - loss: 1.9872 - accuracy: 0.3439 - val_loss: 1.9214 - val_accuracy: 0.3650
# Epoch 96/200
# 50/50 [==============================] - 78s 2s/step - loss: 1.9619 - accuracy: 0.3344 - val_loss: 2.0343 - val_accuracy: 0.3205
# Epoch 97/200
# 50/50 [==============================] - 78s 2s/step - loss: 2.0252 - accuracy: 0.3280 - val_loss: 1.8996 - val_accuracy: 0.3561
# Epoch 98/200
# 50/50 [==============================] - 78s 2s/step - loss: 2.0139 - accuracy: 0.3382 - val_loss: 1.8906 - val_accuracy: 0.3591
# Epoch 99/200
# 50/50 [==============================] - 78s 2s/step - loss: 1.9484 - accuracy: 0.3382 - val_loss: 2.0156 - val_accuracy: 0.3383
# Epoch 100/200
# 50/50 [==============================] - 78s 2s/step - loss: 1.9623 - accuracy: 0.3299 - val_loss: 1.8384 - val_accuracy: 0.3769
# Epoch 101/200
# 50/50 [==============================] - 79s 2s/step - loss: 1.9775 - accuracy: 0.3395 - val_loss: 1.9262 - val_accuracy: 0.3680
# Epoch 102/200
# 50/50 [==============================] - 78s 2s/step - loss: 1.9389 - accuracy: 0.3433 - val_loss: 2.0812 - val_accuracy: 0.3561
# Epoch 103/200
# 50/50 [==============================] - 78s 2s/step - loss: 1.9843 - accuracy: 0.3318 - val_loss: 2.0519 - val_accuracy: 0.3531
# Epoch 104/200
# 50/50 [==============================] - 78s 2s/step - loss: 1.9552 - accuracy: 0.3287 - val_loss: 1.8994 - val_accuracy: 0.3650
# Epoch 105/200
# 50/50 [==============================] - 78s 2s/step - loss: 1.9458 - accuracy: 0.3516 - val_loss: 1.9795 - val_accuracy: 0.3650
# Epoch 106/200
# 50/50 [==============================] - 78s 2s/step - loss: 1.9205 - accuracy: 0.3516 - val_loss: 1.8176 - val_accuracy: 0.4065
# Epoch 107/200
# 50/50 [==============================] - 78s 2s/step - loss: 1.9533 - accuracy: 0.3363 - val_loss: 1.9152 - val_accuracy: 0.3769
# Epoch 108/200
# 50/50 [==============================] - 78s 2s/step - loss: 1.9349 - accuracy: 0.3510 - val_loss: 1.9833 - val_accuracy: 0.3858
# Epoch 109/200
# 50/50 [==============================] - 78s 2s/step - loss: 1.8889 - accuracy: 0.3701 - val_loss: 1.9565 - val_accuracy: 0.3680
# Epoch 110/200
# 50/50 [==============================] - 78s 2s/step - loss: 1.
200
# 50/50 [==============================] - 78s 2s/step - loss: 1.7214 - accuracy: 0.4197 - val_loss: 1.7299 - val_accuracy: 0.4570
# Epoch 172/200
# 50/50 [==============================] - 78s 2s/step - loss: 1.7358 - accuracy: 0.4204 - val_loss: 1.7617 - val_accuracy: 0.4154
# Epoch 173/200
# 50/50 [==============================] - 78s 2s/step - loss: 1.7501 - accuracy: 0.4172 - val_loss: 1.7508 - val_accuracy: 0.4184
# Epoch 174/200
# 50/50 [==============================] - 78s 2s/step - loss: 1.7413 - accuracy: 0.4299 - val_loss: 1.7618 - val_accuracy: 0.3828
# Epoch 175/200
# 50/50 [==============================] - 78s 2s/step - loss: 1.7338 - accuracy: 0.4261 - val_loss: 1.7574 - val_accuracy: 0.4095
# Epoch 176/200
# 50/50 [==============================] - 78s 2s/step - loss: 1.7101 - accuracy: 0.4287 - val_loss: 1.7643 - val_accuracy: 0.4510
# Epoch 177/200
# 50/50 [==============================] - 78s 2s/step - loss: 1.7246 - accuracy: 0.4223 - val_loss: 1.7872 - val_accuracy: 0.4214
# Epoch 178/200
# 50/50 [==============================] - 78s 2s/step - loss: 1.6918 - accuracy: 0.4299 - val_loss: 1.7777 - val_accuracy: 0.4303
# Epoch 179/200
# 50/50 [==============================] - 78s 2s/step - loss: 1.7451 - accuracy: 0.4064 - val_loss: 1.7350 - val_accuracy: 0.4540
# Epoch 180/200
# 50/50 [==============================] - 78s 2s/step - loss: 1.7446 - accuracy: 0.4146 - val_loss: 1.8022 - val_accuracy: 0.4095
# Epoch 181/200
# 50/50 [==============================] - 78s 2s/step - loss: 1.7557 - accuracy: 0.4159 - val_loss: 1.9085 - val_accuracy: 0.4006
# Epoch 182/200
# 50/50 [==============================] - 78s 2s/step - loss: 1.7248 - accuracy: 0.4102 - val_loss: 1.8448 - val_accuracy: 0.4154
# Epoch 183/200
# 50/50 [==============================] - 78s 2s/step - loss: 1.7457 - accuracy: 0.4197 - val_loss: 1.8209 - val_accuracy: 0.4332
# Epoch 184/200
# 50/50 [==============================] - 78s 2s/step - loss: 1.6806 - accuracy: 0.4395 - val_loss: 1.7423 - val_accuracy: 0.4125
# Epoch 185/200
# 50/50 [==============================] - 78s 2s/step - loss: 1.7415 - accuracy: 0.4255 - val_loss: 1.8584 - val_accuracy: 0.4125
# Epoch 186/200
# 50/50 [==============================] - 78s 2s/step - loss: 1.7069 - accuracy: 0.4236 - val_loss: 1.8887 - val_accuracy: 0.4154
# Epoch 187/200
# 50/50 [==============================] - 78s 2s/step - loss: 1.7328 - accuracy: 0.4166 - val_loss: 1.8364 - val_accuracy: 0.4125
# Epoch 188/200
# 50/50 [==============================] - 78s 2s/step - loss: 1.7148 - accuracy: 0.4306 - val_loss: 1.9010 - val_accuracy: 0.4214
# Epoch 189/200
# 50/50 [==============================] - 78s 2s/step - loss: 1.7343 - accuracy: 0.4223 - val_loss: 1.8391 - val_accuracy: 0.4243
# Epoch 190/200
# 50/50 [==============================] - 78s 2s/step - loss: 1.7029 - accuracy: 0.4229 - val_loss: 1.8534 - val_accuracy: 0.3798
# Epoch 191/200
# 50/50 [==============================] - 79s 2s/step - loss: 1.7403 - accuracy: 0.4325 - val_loss: 1.7876 - val_accuracy: 0.4451
# Epoch 192/200
# 50/50 [==============================] - 78s 2s/step - loss: 1.7139 - accuracy: 0.4217 - val_loss: 1.7938 - val_accuracy: 0.4184
# Epoch 193/200
# 50/50 [==============================] - 78s 2s/step - loss: 1.6959 - accuracy: 0.4280 - val_loss: 1.8185 - val_accuracy: 0.4214
# Epoch 194/200
# 50/50 [==============================] - 78s 2s/step - loss: 1.6769 - accuracy: 0.4357 - val_loss: 1.7767 - val_accuracy: 0.4510
# Epoch 195/200
# 50/50 [==============================] - 78s 2s/step - loss: 1.8138 - accuracy: 0.3873 - val_loss: 1.7230 - val_accuracy: 0.4451
# Epoch 196/200
# 50/50 [==============================] - 79s 2s/step - loss: 1.7210 - accuracy: 0.4280 - val_loss: 1.7461 - val_accuracy: 0.4243
# Epoch 197/200
# 50/50 [==============================] - 78s 2s/step - loss: 1.6945 - accuracy: 0.4427 - val_loss: 1.7666 - val_accuracy: 0.4154
# Epoch 00197: early stopping

# %%
print("Accuracy of the model on train data is {:.2f}%".format(history.history["accuracy"][-1]*100))
# Out:
# Accuracy of the model on train data is 44.27%

# %%
import matplotlib.pyplot as plt
acc=history.history['accuracy']
val_acc=history.history['val_accuracy']
loss=history.history['loss']
val_loss=history.history['val_loss']

epochs=range(len(acc))

fig = plt.figure(figsize=(14,7))
plt.plot(epochs, acc, 'r', label="Training Accuracy")
plt.plot(epochs, val_acc, 'b', label="Validation Accuracy")
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and validation accuracy')
plt.legend(loc='lower right')
plt.show()

# %%
fig2 = plt.figure(figsize=(14,7))
plt.plot(epochs, loss, 'r', label="Training Loss")
plt.plot(epochs, val_loss, 'b', label="Validation Loss")
plt.legend(loc='upper right')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and validation loss')
# Out:
# Text(0.5, 1.0, 'Training and validation loss')

# %% [markdown]
# Save Model

# %%
# model.save('/content/drive/MyDrive/indosnake/model/snake_model.h5')

# %%
modelku = '/content/drive/MyDrive/Colab Notebooks/indosnake/snake_model.tflite'
tf_lite_converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = tf_lite_converter.convert()

tflite_model_name = modelku
open(tflite_model_name, "wb").write(tflite_model)
# Out:
# WARNING:absl:Found untraced functions such as dropout_layer_call_fn, dropout_layer_call_and_return_conditional_losses, dropout_1_layer_call_fn, dropout_1_layer_call_and_return_conditional_losses, dropout_2_layer_call_fn while saving (showing 5 of 20). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /tmp/tmpbp3awmjf/assets
# INFO:tensorflow:Assets written to: /tmp/tmpbp3awmjf/assets
# 3323960

# %%
valid = '/content/drive/MyDrive/Indo_snake/Single Pred/'
test_img = os.listdir(os.path.join(valid))

test_df = pd.DataFrame({'Image': test_img})
test_df.head()
# Out:
#                         Image
# 0  Calamaria schlegeli 1.jpeg
# 1  Calamaria schlegeli 2.jpeg
# 2   Calamaria schlegeli 3.JPG
# 3     Boiga Dendrophila 1.jpg
# 4     Boiga Dendrophila 2.jpg

# %%
valid_gen = ImageDataGenerator(rescale=1./255)

valid_generator = valid_gen.flow_from_dataframe(
    test_df, 
    valid, 
    x_col = 'Image',
    y_col = None,
    class_mode = None,
    target_size = (150, 200),
    batch_size = 1,
    shuffle = False
)
# Out:
# Found 51 validated image filenames.

# %%
predict = model.predict_generator(valid_generator, steps = 51)
predict
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:2001: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   warnings.warn('`Model.predict_generator` is deprecated and '
# array([[1.87846366e-03, 1.90057792e-02, 1.12954173e-02, 2.48472080e-01,
#         1.94126084e-01, 6.25124872e-02, 1.18306778e-01, 3.29312049e-02,
#         1.76798739e-02, 1.47311867e-03, 1.42834587e-02, 2.28254143e-02,
#         4.65739034e-02, 5.82384989e-02, 9.07367393e-02, 5.88462166e-02,
#         8.14387691e-04],
#        [5.98697504e-03, 2.50655003e-02, 2.41144188e-02, 1.36384875e-01,
#         1.11700267e-01, 3.78465727e-02, 5.38313612e-02, 7.80364573e-02,
#         7.62316436e-02, 1.21838264e-02, 1.40909171e-02, 2.34337896e-02,
#         5.20256236e-02, 6.69867396e-02, 1.33371338e-01, 1.43350631e-01,
#         5.35908435e-03],
#        [1.13935187e-01, 4.59423475e-03, 8.82893503e-02, 6.12618402e-03,
#         2.36881211e-01, 5.32214239e-04, 4.23738539e-01, 1.74181609e-04,
#         6.66460039e-07, 1.07877865e-03, 2.99575011e-04, 2.11454351e-02,
#         1.58548877e-02, 6.66601732e-02, 3.41644161e-04, 2.01026108e-02,
#         2.45072326e-04],
#        [4.91979122e-01, 8.14182567e-04, 3.65304619e-01, 4.61672425e-05,
#         9.43718757e-03, 1.63303514e-06, 1.11142620e-02, 1.39806580e-04,
#         8.21743242e-07, 4.65348223e-03, 7.26803992e-05, 8.10378231e-03,
#         6.93682954e-03, 2.10246351e-02, 2.80151144e-04, 7.99120441e-02,
#         1.78567978e-04],
#        [9.97946084e-01, 1.71928208e-18, 2.05395487e-03, 3.74904481e-26,
#         6.94414452e-02, 5.51691838e-02, 1.65600181e-02, 6.50922805e-02,
#         9.47664008e-02, 1.22850604e-01, 1.39783630e-02, 3.84394452e-02,
#         4.99423929e-02, 8.65418538e-02, 6.11339547e-02, 1.76033556e-01,
#         5.62687069e-02],
#        [2.47315948e-13, 6.88149200e-08, 3.20140655e-15, 1.20504066e-14,
#         6.71221585e-12, 5.39292081e-13, 2.42142461e-12, 3.32325740e-08,
#         2.31934827e-08, 1.54564351e-01, 6.38292587e-12, 1.09359981e-07,
#         8.04369449e-07, 5.34417904e-06, 1.37536801e-10, 2.33342305e-08,
#         8.45429301e-01],
#        [8.53046775e-03, 1.29610365e-02, 2.02127127e-03, 5.68815554e-03,
#         1.63461659e-02, 1.99678377e-03, 1.37493247e-02, 5.06166928e-03,
#         2.97280960e-03, 4.34680611e-01, 8.70853139e-04, 6.11588266e-03,
#         2.50459965e-02, 8.22812691e-02, 2.41569965e-03, 1.74298324e-02,
#         3.61832231e-01],
#        [1.13763122e-06, 1.19779215e-04, 1.48797270e-07, 3.16205643e-07,
#         2.64443588e-06, 3.21415882e-07, 1.15275816e-06, 1.66400408e-04,
#         4.44088546e-05, 2.90547132e-01, 2.52700124e-06, 7.74781220e-05,
#         1.50459842e-03, 1.48361793e-03, 1.37803054e-05, 1.60248834e-04,
#         7.05874383e-01]], dtype=float32)

# %%
# Identifying the classes

label_map = dict((v,k) for k,v in train_generator.class_indices.items())
label_map
# Out:
# {0: 'Boiga Dendrophila  (Ular Cincin Emas)',
#  1: 'Bungarus Candidus (Ular Weling)',
#  2: 'Bungarus Fasciatus (Ular Welang)',
#  3: 'Bungarus Flaviceps (Krait Kepala Merah)',
#  4: 'Calamaria Schlegeli (Ular Buluh Berkepala Merah)',
#  5: 'Calliophis Bivirgatus (Ular Cabai Besar)',
#  6: 'Calliophis Intestinalis (Ular Cabai Kecil)',
#  7: 'Calloselasma Rhodostoma (Ular Tanah)',
#  8: 'Daboia Siamensis (Ular Bandotan Puspa)',
#  9: 'Gonyosoma Oxycephalum (Ular Bajing)',
#  10: 'Hydrophis Belcheri (Ular Laut Belcher )',
#  11: 'Lycodon Subcinctus (Ular Cicak)',
#  12: 'Naja sumatrana (Ular Kobra Sumatra)',
#  13: 'Ophiophagus Hannah (King Cobra)',
#  14: 'Oxyuranus Scutellatus (Ular Taipan Pesisir)',
#  15: 'Rhabdophis Subminiatus (Ular Picung)',
#  16: 'Trimeresurus Albolabris (Ular Bangkai Laut)'}

# %%
test_df['Label'] = np.argmax(predict, axis = -1)
test_df['Label']
# Out:
# 0      3
# 1     15
# 2      6
# 3      0
# 4      0
# 5      0
# 6      9
# 7     11
# 8     15
# 9      7
# 10     0
# 11     2
# 12     3
# 13     3
# 14     3
# 15     5
# 16     5
# 17     3
# 18     3
# 19     6
# 20     6
# 21     8
# 22     8
# 23     8
# 24     8
# 25    14
# 26     8
# 27     9
# 28     9
# 29     9
# 30    10
# 31    10
# 32    10
# 33     7
# 34    10
# 35    11
# 36    14
# 37    15
# 38    14
# 39     7
# 40    15
# 41     4
# 42    15
# 43    15
# 44    15
# 45    15
# 46    15
# 47    15
# 48    16
# 49     9
# 50    16
# Name: Label, dtype: int64

# %%
actual_df = pd.read_csv('/content/drive/MyDrive/Indo_snake/test.csv')
y_true = actual_df['labels']
y_pred = test_df['Label']
print(y_true)
# Out:
# 0      0
# 1      0
# 2      0
# 3      1
# 4      1
# 5      1
# 6      2
# 7      2
# 8      2
# 9      3
# 10     3
# 11     3
# 12     4
# 13     4
# 14     4
# 15     5
# 16     5
# 17     5
# 18     6
# 19     6
# 20     6
# 21     7
# 22     7
# 23     7
# 24     8
# 25     8
# 26     8
# 27     9
# 28     9
# 29     9
# 30    10
# 31    10
# 32    10
# 33    11
# 34    11
# 35    11
# 36    12
# 37    12
# 38    12
# 39    13
# 40    13
# 41    13
# 42    14
# 43    14
# 44    14
# 45    15
# 46    15
# 47    15
# 48    16
# 49    16
# 50    16
# Name: labels, dtype: int64

# %%
from sklearn.metrics import confusion_matrix
from mlxtend.plotting import plot_confusion_matrix
cm = confusion_matrix(y_true,y_pred)
plot_confusion_matrix(conf_mat = cm,figsize=(8,7));

# %%
v = random.randint(0, 12)

sample_test = test_df.iloc[v:(v+18)].reset_index(drop = True)
sample_test.head()

plt.figure(figsize=(12, 24))
for index, row in sample_test.iterrows():
    filename = row['Image']
    category = row['Label']
    img = load_img(valid + filename, target_size = (150, 200))
    plt.subplot(6, 3, index + 1)
    plt.imshow(img)
    plt.xlabel(filename + ' ( ' + "{}".format(category) + ' )' )
plt.tight_layout()
plt.show()

# %%
test_df['Label'] = test_df['Label'].replace(label_map)
test_df
# Out:
#                              Image                                             Label
# 0       Calamaria schlegeli 1.jpeg           Bungarus Flaviceps (Krait Kepala Merah)
# 1       Calamaria schlegeli 2.jpeg              Rhabdophis Subminiatus (Ular Picung)
# 2        Calamaria schlegeli 3.JPG        Calliophis Intestinalis (Ular Cabai Kecil)
# 3          Boiga Dendrophila 1.jpg             Boiga Dendrophila  (Ular Cincin Emas)
# 4          Boiga Dendrophila 2.jpg             Boiga Dendrophila  (Ular Cincin Emas)
# 5          Boiga Dendrophila 3.jpg             Boiga Dendrophila  (Ular Cincin Emas)
# 6         Bungarus Candidus 1.jpeg               Gonyosoma Oxycephalum (Ular Bajing)
# 7         Bungarus Candidus 2.jpeg                   Lycodon Subcinctus (Ular Cicak)
# 8         Bungarus Candidus 3.jpeg              Rhabdophis Subminiatus (Ular Picung)
# 9        Bungarus Fasciatus 1.jpeg              Calloselasma Rhodostoma (Ular Tanah)
# 10       Bungarus Fasciatus 2.jpeg             Boiga Dendrophila  (Ular Cincin Emas)
# 11        Bungarus Fasciatus 3.jpg                  Bungarus Fasciatus (Ular Welang)
# 12        Bungarus Flaviceps 1.jpg           Bungarus Flaviceps (Krait Kepala Merah)
# 13       Bungarus Flaviceps 2.jpeg           Bungarus Flaviceps (Krait Kepala Merah)
# 14        Bungarus Flaviceps 3.JPG           Bungarus Flaviceps (Krait Kepala Merah)
# 15    Calliophis Bivirgatus 1.jpeg          Calliophis Bivirgatus (Ular Cabai Besar)
# 16    Calliophis Bivirgatus 2.jpeg          Calliophis Bivirgatus (Ular Cabai Besar)
# 17     Calliophis Bivirgatus 3.JPG           Bungarus Flaviceps (Krait Kepala Merah)
