# %% [markdown]
# <a href="https://colab.research.google.com/github/icahlatif/My_List/blob/master/Copy_of_42618021_UAS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

import os
import random
import shutil

import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img

import matplotlib.pyplot as plt

# %%
train_dir = "/content/drive/MyDrive/Indo_snake/Training/"
test_dir = "/content/drive/MyDrive/Indo_snake/Testing/"

# %%
# Displaying random image from the dataset
fig, ax = plt.subplots(4, 5, figsize=(15, 10))

sample_paper = random.choice(os.listdir(train_dir + "Boiga Dendrophila  (Ular Cincin Emas)"))
image = load_img(train_dir + "Boiga Dendrophila  (Ular Cincin Emas)/" + sample_paper)
ax[0, 0].imshow(image)
ax[0, 0].set_title("Ular Cincin")


sample_paper = random.choice(os.listdir(train_dir + "Bungarus Candidus (Ular Weling)"))
image = load_img(train_dir + "Bungarus Candidus (Ular Weling)/" + sample_paper)
ax[0, 1].imshow(image)
ax[0, 1].set_title("Ular Weling")

sample_paper = random.choice(os.listdir(train_dir + "Bungarus Fasciatus (Ular Welang)"))
image = load_img(train_dir + "Bungarus Fasciatus (Ular Welang)/" + sample_paper)
ax[0, 2].imshow(image)
ax[0, 2].set_title("Ular Welang")


sample_paper = random.choice(os.listdir(train_dir + "Bungarus Flaviceps (Krait Kepala Merah)"))
image = load_img(train_dir + "Bungarus Flaviceps (Krait Kepala Merah)/" + sample_paper)
ax[0, 3].imshow(image)
ax[0, 3].set_title("Ular Krait")


sample_paper = random.choice(os.listdir(train_dir + "Calamaria Schlegeli (Ular Buluh Berkepala Merah)"))
image = load_img(train_dir + "Calamaria Schlegeli (Ular Buluh Berkepala Merah)/" + sample_paper)
ax[0, 4].imshow(image)
ax[0, 4].set_title("Ular Calamaria")


sample_paper = random.choice(os.listdir(train_dir + "Calliophis Bivirgatus (Ular Cabai Besar)"))
image = load_img(train_dir + "Calliophis Bivirgatus (Ular Cabai Besar)/" + sample_paper)
ax[1, 0].imshow(image)
ax[1, 0].set_title("Ular Cabai Besar")
ax[1, 0].axis("Off")

sample_paper = random.choice(os.listdir(train_dir + "Calliophis Intestinalis (Ular Cabai Kecil)"))
image = load_img(train_dir + "Calliophis Intestinalis (Ular Cabai Kecil)/" + sample_paper)
ax[1, 1].imshow(image)
ax[1, 1].set_title("Ular Cabai Kecil")
ax[1, 1].axis("Off")

sample_paper = random.choice(os.listdir(train_dir + "Calloselasma Rhodostoma (Ular Tanah)"))
image = load_img(train_dir + "Calloselasma Rhodostoma (Ular Tanah)/" + sample_paper)
ax[1, 2].imshow(image)
ax[1, 2].set_title("Ular Tanah")
ax[1, 2].axis("Off")

sample_paper = random.choice(os.listdir(train_dir + "Daboia Siamensis (Ular Bandotan Puspa)"))
image = load_img(train_dir + "Daboia Siamensis (Ular Bandotan Puspa)/" + sample_paper)
ax[1, 3].imshow(image)
ax[1, 3].set_title("Ular Bandotan Puspa")
ax[1, 3].axis("Off")

sample_paper = random.choice(os.listdir(train_dir + "Gonyosoma Oxycephalum (Ular Bajing)"))
image = load_img(train_dir + "Gonyosoma Oxycephalum (Ular Bajing)/" + sample_paper)
ax[1, 4].imshow(image)
ax[1, 4].set_title("Ular Bajing")
ax[1, 4].axis("Off")

sample_paper = random.choice(os.listdir(train_dir + "Hydrophis Belcheri (Ular Laut Belcher )"))
image = load_img(train_dir + "Hydrophis Belcheri (Ular Laut Belcher )/" + sample_paper)
ax[2, 0].imshow(image)
ax[2, 0].set_title("Ular Belcher")
ax[2, 0].axis("Off")

sample_paper = random.choice(os.listdir(train_dir + "Lycodon Subcinctus (Ular Cicak)"))
image = load_img(train_dir + "Lycodon Subcinctus (Ular Cicak)/" + sample_paper)
ax[2, 1].imshow(image)
ax[2, 1].set_title("Ular Cicak")
ax[2, 1].axis("Off")

sample_paper = random.choice(os.listdir(train_dir + "Naja sumatrana (Ular Kobra Sumatra)"))
image = load_img(train_dir + "Naja sumatrana (Ular Kobra Sumatra)/" + sample_paper)
ax[2, 2].imshow(image)
ax[2, 2].set_title("Ular Kobra Sumatra")
ax[2, 2].axis("Off")

sample_paper = random.choice(os.listdir(train_dir + "Ophiophagus Hannah (King Cobra)"))
image = load_img(train_dir + "Ophiophagus Hannah (King Cobra)/" + sample_paper)
ax[2, 3].imshow(image)
ax[2, 3].set_title("King Cobra")
ax[2, 3].axis("Off")

sample_paper = random.choice(os.listdir(train_dir + "Oxyuranus Scutellatus (Ular Taipan Pesisir)"))
image = load_img(train_dir + "Oxyuranus Scutellatus (Ular Taipan Pesisir)/" + sample_paper)
ax[2, 4].imshow(image)
ax[2, 4].set_title("Ular Taipan Pesisir")
ax[2, 4].axis("Off")

ax[3, 0].axis("Off")
sample_paper = random.choice(os.listdir(train_dir + "Rhabdophis Subminiatus (Ular Picung)"))
image = load_img(train_dir + "Rhabdophis Subminiatus (Ular Picung)/" + sample_paper)
ax[3, 1].imshow(image)
ax[3, 1].set_title("Ular Picung")
ax[3, 1].axis("Off")
ax[3, 2].axis("Off")
sample_paper = random.choice(os.listdir(train_dir + "Trimeresurus Albolabris (Ular Bangkai Laut)"))
image = load_img(train_dir + "Trimeresurus Albolabris (Ular Bangkai Laut)/" + sample_paper)
ax[3, 3].imshow(image)
ax[3, 3].set_title("Ular Bangkai Laut")
ax[3, 3].axis("Off")
ax[3, 4].axis("Off")
# Out:
# (0.0, 1.0, 0.0, 1.0)

# %%
train_datagen = ImageDataGenerator(
      rescale=1./255,
      rotation_range=30,
      width_shift_range=0.4, # Shifting image width by 40%
      height_shift_range=0.4,# Shifting image height by 40%
      shear_range=0.2,       # Rotation across X-axis by 20%
      zoom_range=0.3,        # Image zooming by 30%
      vertical_flip = True,
      horizontal_flip=True)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size = (150, 200),
    class_mode = 'categorical',
    batch_size = 32
)

test_datagen = ImageDataGenerator(
      rescale=1./255)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size = (150, 200),
    class_mode = 'categorical',
    batch_size = 32
)
# Out:
# Found 1570 images belonging to 17 classes.
# Found 337 images belonging to 17 classes.

# %%
from keras.layers import Dense, Dropout, Flatten
model = tf.keras.models.Sequential([
    
    tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(150, 200, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),
    Dropout(0.25),

    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    Dropout(0.25),
    
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    Dropout(0.25),
    
    tf.keras.layers.Flatten(),
    
    tf.keras.layers.Dense(32, activation='relu'),
    Dropout(0.25),
    tf.keras.layers.Dense(17, activation='softmax')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 148, 198, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 74, 99, 32)        0
# _________________________________________________________________
# module_wrapper (ModuleWrappe (None, 74, 99, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 72, 97, 32)        9248
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 36, 48, 32)        0
# _________________________________________________________________
# module_wrapper_1 (ModuleWrap (None, 36, 48, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 34, 46, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 17, 23, 64)        0
# _________________________________________________________________
# module_wrapper_2 (ModuleWrap (None, 17, 23, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 25024)             0
# _________________________________________________________________
# dense (Dense)                (None, 32)                800800
# _________________________________________________________________
# module_wrapper_3 (ModuleWrap (None, 32)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 17)                561
# =================================================================
# Total params: 830,001
# Trainable params: 830,001
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss = 'categorical_crossentropy',
              optimizer = 'adam',
              metrics = ['accuracy'])

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=30)

# %%
history = model.fit_generator(train_generator,
                              epochs=200,
                              verbose=1,
                              validation_data=test_generator, 
                              callbacks = [es])
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1940: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/200
# 50/50 [==============================] - 958s 19s/step - loss: 2.8824 - accuracy: 0.0561 - val_loss: 2.8332 - val_accuracy: 0.0564
# Epoch 2/200
# 50/50 [==============================] - 22s 440ms/step - loss: 2.8331 - accuracy: 0.0573 - val_loss: 2.8332 - val_accuracy: 0.0593
# Epoch 3/200
# 50/50 [==============================] - 22s 436ms/step - loss: 2.8338 - accuracy: 0.0599 - val_loss: 2.8330 - val_accuracy: 0.0593
# Epoch 4/200
# 50/50 [==============================] - 22s 438ms/step - loss: 2.8270 - accuracy: 0.0688 - val_loss: 2.8151 - val_accuracy: 0.0623
# Epoch 5/200
# 50/50 [==============================] - 21s 427ms/step - loss: 2.7955 - accuracy: 0.0892 - val_loss: 2.7700 - val_accuracy: 0.1187
# Epoch 6/200
# 50/50 [==============================] - 22s 432ms/step - loss: 2.7583 - accuracy: 0.0936 - val_loss: 2.6981 - val_accuracy: 0.1157
# Epoch 7/200
# 50/50 [==============================] - 22s 431ms/step - loss: 2.7291 - accuracy: 0.1197 - val_loss: 2.6703 - val_accuracy: 0.1217
# Epoch 8/200
# 50/50 [==============================] - 21s 429ms/step - loss: 2.7161 - accuracy: 0.1236 - val_loss: 2.6268 - val_accuracy: 0.1217
# Epoch 9/200
# 50/50 [==============================] - 22s 441ms/step - loss: 2.6681 - accuracy: 0.1248 - val_loss: 2.5917 - val_accuracy: 0.1217
# Epoch 10/200
# 50/50 [==============================] - 22s 438ms/step - loss: 2.6443 - accuracy: 0.1236 - val_loss: 2.5814 - val_accuracy: 0.1187
# Epoch 11/200
# 50/50 [==============================] - 22s 437ms/step - loss: 2.6644 - accuracy: 0.1185 - val_loss: 2.5739 - val_accuracy: 0.1187
# Epoch 12/200
# 50/50 [==============================] - 22s 435ms/step - loss: 2.6423 - accuracy: 0.1197 - val_loss: 2.5672 - val_accuracy: 0.1365
# Epoch 13/200
# 50/50 [==============================] - 22s 446ms/step - loss: 2.6589 - accuracy: 0.1025 - val_loss: 2.5782 - val_accuracy: 0.0920
# Epoch 14/200
# 50/50 [==============================] - 22s 440ms/step - loss: 2.6225 - accuracy: 0.1274 - val_loss: 2.5307 - val_accuracy: 0.1246
# Epoch 15/200
# 50/50 [==============================] - 22s 435ms/step - loss: 2.6239 - accuracy: 0.1185 - val_loss: 2.5445 - val_accuracy: 0.1187
# Epoch 16/200
# 50/50 [==============================] - 21s 429ms/step - loss: 2.6195 - accuracy: 0.1140 - val_loss: 2.5814 - val_accuracy: 0.1098
# Epoch 17/200
# 50/50 [==============================] - 21s 429ms/step - loss: 2.6263 - accuracy: 0.1153 - val_loss: 2.5309 - val_accuracy: 0.1365
# Epoch 18/200
# 50/50 [==============================] - 22s 429ms/step - loss: 2.6059 - accuracy: 0.1280 - val_loss: 2.5656 - val_accuracy: 0.1395
# Epoch 19/200
# 50/50 [==============================] - 21s 430ms/step - loss: 2.6087 - accuracy: 0.1191 - val_loss: 2.5041 - val_accuracy: 0.1543
# Epoch 20/200
# 50/50 [==============================] - 22s 437ms/step - loss: 2.6038 - accuracy: 0.1210 - val_loss: 2.4907 - val_accuracy: 0.1335
# Epoch 21/200
# 50/50 [==============================] - 22s 440ms/step - loss: 2.6012 - accuracy: 0.1172 - val_loss: 2.5034 - val_accuracy: 0.1157
# Epoch 22/200
# 50/50 [==============================] - 22s 446ms/step - loss: 2.5769 - accuracy: 0.1229 - val_loss: 2.5113 - val_accuracy: 0.1246
# Epoch 23/200
# 50/50 [==============================] - 22s 436ms/step - loss: 2.6103 - accuracy: 0.1229 - val_loss: 2.5301 - val_accuracy: 0.1246
# Epoch 24/200
# 50/50 [==============================] - 22s 431ms/step - loss: 2.5759 - accuracy: 0.1293 - val_loss: 2.4961 - val_accuracy: 0.1306
# Epoch 25/200
# 50/50 [==============================] - 22s 439ms/step - loss: 2.5909 - accuracy: 0.1217 - val_loss: 2.4766 - val_accuracy: 0.1276
# Epoch 26/200
# 50/50 [==============================] - 22s 443ms/step - loss: 2.5701 - accuracy: 0.1427 - val_loss: 2.5278 - val_accuracy: 0.1424
# Epoch 27/200
# 50/50 [==============================] - 22s 429ms/step - loss: 2.5488 - accuracy: 0.1338 - val_loss: 2.4786 - val_accuracy: 0.1335
# Epoch 28/200
# 50/50 [==============================] - 21s 429ms/step - loss: 2.5793 - accuracy: 0.1248 - val_loss: 2.4934 - val_accuracy: 0.1484
# Epoch 29/200
# 50/50 [==============================] - 21s 429ms/step - loss: 2.6039 - accuracy: 0.1280 - val_loss: 2.5039 - val_accuracy: 0.1335
# Epoch 30/200
# 50/50 [==============================] - 22s 433ms/step - loss: 2.5605 - accuracy: 0.1376 - val_loss: 2.4679 - val_accuracy: 0.1276
# Epoch 31/200
# 50/50 [==============================] - 22s 443ms/step - loss: 2.5673 - accuracy: 0.1312 - val_loss: 2.4699 - val_accuracy: 0.1454
# Epoch 32/200
# 50/50 [==============================] - 22s 439ms/step - loss: 2.5435 - accuracy: 0.1293 - val_loss: 2.4780 - val_accuracy: 0.1484
# Epoch 33/200
# 50/50 [==============================] - 22s 439ms/step - loss: 2.5461 - accuracy: 0.1382 - val_loss: 2.4655 - val_accuracy: 0.1395
# Epoch 34/200
# 50/50 [==============================] - 22s 439ms/step - loss: 2.5575 - accuracy: 0.1318 - val_loss: 2.4664 - val_accuracy: 0.1573
# Epoch 35/200
# 50/50 [==============================] - 22s 436ms/step - loss: 2.5271 - accuracy: 0.1318 - val_loss: 2.5349 - val_accuracy: 0.1573
# Epoch 36/200
# 50/50 [==============================] - 22s 430ms/step - loss: 2.5499 - accuracy: 0.1363 - val_loss: 2.4758 - val_accuracy: 0.1543
# Epoch 37/200
# 50/50 [==============================] - 21s 426ms/step - loss: 2.5719 - accuracy: 0.1344 - val_loss: 2.4911 - val_accuracy: 0.1513
# Epoch 38/200
# 50/50 [==============================] - 21s 427ms/step - loss: 2.5354 - accuracy: 0.1433 - val_loss: 2.4893 - val_accuracy: 0.1721
# Epoch 39/200
# 50/50 [==============================] - 22s 434ms/step - loss: 2.5460 - accuracy: 0.1414 - val_loss: 2.4595 - val_accuracy: 0.1484
# Epoch 40/200
# 50/50 [==============================] - 22s 434ms/step - loss: 2.5486 - accuracy: 0.1331 - val_loss: 2.4413 - val_accuracy: 0.1602
# Epoch 41/200
# 50/50 [==============================] - 22s 438ms/step - loss: 2.5255 - accuracy: 0.1242 - val_loss: 2.4948 - val_accuracy: 0.1573
# Epoch 42/200
# 50/50 [==============================] - 22s 437ms/step - loss: 2.5376 - accuracy: 0.1312 - val_loss: 2.4254 - val_accuracy: 0.1662
# Epoch 43/200
# 50/50 [==============================] - 22s 436ms/step - loss: 2.5282 - accuracy: 0.1414 - val_loss: 2.4660 - val_accuracy: 0.1929
# Epoch 44/200
# 50/50 [==============================] - 22s 440ms/step - loss: 2.5175 - accuracy: 0.1357 - val_loss: 2.4601 - val_accuracy: 0.1869
# Epoch 45/200
# 50/50 [==============================] - 22s 437ms/step - loss: 2.5186 - accuracy: 0.1707 - val_loss: 2.4496 - val_accuracy: 0.1929
# Epoch 46/200
# 50/50 [==============================] - 21s 430ms/step - loss: 2.5373 - accuracy: 0.1669 - val_loss: 2.4711 - val_accuracy: 0.1988
# Epoch 47/200
# 50/50 [==============================] - 22s 430ms/step - loss: 2.5488 - accuracy: 0.1618 - val_loss: 2.7819 - val_accuracy: 0.0979
# Epoch 48/200
# 50/50 [==============================] - 22s 434ms/step - loss: 2.6676 - accuracy: 0.1229 - val_loss: 2.5001 - val_accuracy: 0.1721
# Epoch 49/200
# 50/50 [==============================] - 22s 437ms/step - loss: 2.5381 - accuracy: 0.1611 - val_loss: 2.4411 - val_accuracy: 0.2136
# Epoch 50/200
# 50/50 [==============================] - 22s 436ms/step - loss: 2.5057 - accuracy: 0.1624 - val_loss: 2.4361 - val_accuracy: 0.2285
# Epoch 51/200
# 50/50 [==============================] - 22s 437ms/step - loss: 2.5178 - accuracy: 0.1790 - val_loss: 2.4170 - val_accuracy: 0.2196
# Epoch 52/200
# 50/50 [==============================] - 22s 438ms/step - loss: 2.5001 - accuracy: 0.1898 - val_loss: 2.3777 - val_accuracy: 0.2018
# Epoch 53/200
# 50/50 [==============================] - 22s 436ms/step - loss: 2.4848 - accuracy: 0.1758 - val_loss: 2.3534 - val_accuracy: 0.2136
# Epoch 54/200
# 50/50 [==============================] - 22s 440ms/step - loss: 2.4656 - accuracy: 0.1803 - val_loss: 2.4478 - val_accuracy: 0.1988
# Epoch 55/200
# 50/50 [==============================] - 22s 436ms/step - loss: 2.4546 - accuracy: 0.1828 - val_loss: 2.3999 - val_accuracy: 0.2136
# Epoch 56/200
# 50/50 [==============================] - 22s 438ms/step - loss: 2.4217 - accuracy: 0.1936 - val_loss: 2.3006 - val_accuracy: 0.2166
# Epoch 57/200
# 50/50 [==============================] - 22s 434ms/step - loss: 2.4359 - accuracy: 0.1943 - val_loss: 2.3699 - val_accuracy: 0.2226
# Epoch 58/200
# 50/50 [==============================] - 22s 439ms/step - loss: 2.4294 - accuracy: 0.1803 - val_loss: 2.3346 - val_accuracy: 0.2493
# Epoch 59/200
# 50/50 [==============================] - 22s 429ms/step - loss: 2.4080 - accuracy: 0.1994 - val_loss: 2.3160 - val_accuracy: 0.2255
# Epoch 60/200
# 50/50 [==============================] - 21s 428ms/step - loss: 2.3754 - accuracy: 0.2159 - val_loss: 2.3732 - val_accuracy: 0.2196
# Epoch 61/200
# 50/50 [==============================] - 22s 438ms/step - loss: 2.3956 - accuracy: 0.2032 - val_loss: 2.3122 - val_accuracy: 0.2285
# Epoch 62/200
# 50/50 [==============================] - 22s 439ms/step - loss: 2.4096 - accuracy: 0.2013 - val_loss: 2.3117 - val_accuracy: 0.2018
# Epoch 63/200
# 50/50 [==============================] - 22s 438ms/step - loss: 2.3590 - accuracy: 0.1955 - val_loss: 2.3166 - val_accuracy: 0.1958
# Epoch 64/200
# 50/50 [==============================] - 22s 436ms/step - loss: 2.3647 - accuracy: 0.2102 - val_loss: 2.2625 - val_accuracy: 0.2582
# Epoch 65/200
# 50/50 [==============================] - 22s 436ms/step - loss: 2.3666 - accuracy: 0.2210 - val_loss: 2.3022 - val_accuracy: 0.2226
# Epoch 66/200
# 50/50 [==============================] - 22s 439ms/step - loss: 2.3838 - accuracy: 0.2166 - val_loss: 2.3615 - val_accuracy: 0.2255
# Epoch 67/200
# 50/50 [==============================] - 22s 438ms/step - loss: 2.3382 - accuracy: 0.2229 - val_loss: 2.3137 - val_accuracy: 0.2107
# Epoch 68/200
# 50/50 [==============================] - 22s 434ms/step - loss: 2.3446 - accuracy: 0.2293 - val_loss: 2.2971 - val_accuracy: 0.2344
# Epoch 69/200
# 50/50 [==============================] - 22s 432ms/step - loss: 2.3217 - accuracy: 0.2166 - val_loss: 2.2648 - val_accuracy: 0.2344
# Epoch 70/200
# 50/50 [==============================] - 21s 429ms/step - loss: 2.3117 - accuracy: 0.2318 - val_loss: 2.2773 - val_accuracy: 0.2107
# Epoch 71/200
# 50/50 [==============================] - 22s 434ms/step - loss: 2.3361 - accuracy: 0.2178 - val_loss: 2.2709 - val_accuracy: 0.2404
# Epoch 72/200
# 50/50 [==============================] - 22s 440ms/step - loss: 2.2922 - accuracy: 0.2229 - val_loss: 2.2581 - val_accuracy: 0.2433
# Epoch 73/200
# 50/50 [==============================] - 22s 441ms/step - loss: 2.3214 - accuracy: 0.2159 - val_loss: 2.3024 - val_accuracy: 0.2136
# Epoch 74/200
# 50/50 [==============================] - 22s 442ms/step - loss: 2.3050 - accuracy: 0.2350 - val_loss: 2.2426 - val_accuracy: 0.2433
# Epoch 75/200
# 50/50 [==============================] - 22s 439ms/step - loss: 2.3203 - accuracy: 0.2140 - val_loss: 2.2958 - val_accuracy: 0.2136
# Epoch 76/200
# 50/50 [==============================] - 22s 440ms/step - loss: 2.2930 - accuracy: 0.2172 - val_loss: 2.2157 - val_accuracy: 0.2700
# Epoch 77/200
# 50/50 [==============================] - 22s 441ms/step - loss: 2.3341 - accuracy: 0.2217 - val_loss: 2.3474 - val_accuracy: 0.2315
# Epoch 78/200
# 50/50 [==============================] - 22s 441ms/step - loss: 2.3004 - accuracy: 0.2331 - val_loss: 2.2236 - val_accuracy: 0.2463
# Epoch 79/200
# 50/50 [==============================] - 22s 433ms/step - loss: 2.2782 - accuracy: 0.2318 - val_loss: 2.2264 - val_accuracy: 0.2315
# Epoch 80/200
# 50/50 [==============================] - 22s 433ms/step - loss: 2.2773 - accuracy: 0.2363 - val_loss: 2.2188 - val_accuracy: 0.2582
# Epoch 81/200
# 50/50 [==============================] - 22s 435ms/step - loss: 2.2817 - accuracy: 0.2248 - val_loss: 2.1558 - val_accuracy: 0.2493
# Epoch 82/200
# 50/50 [==============================] - 22s 433ms/step - loss: 2.3670 - accuracy: 0.2140 - val_loss: 2.3286 - val_accuracy: 0.2196
# Epoch 83/200
# 50/50 [==============================] - 22s 437ms/step - loss: 2.2853 - accuracy: 0.2191 - val_loss: 2.2278 - val_accuracy: 0.2463
# Epoch 84/200
# 50/50 [==============================] - 22s 440ms/step - loss: 2.2879 - accuracy: 0.2197 - val_loss: 2.2760 - val_accuracy: 0.2463
# Epoch 85/200
# 50/50 [==============================] - 22s 445ms/step - loss: 2.2468 - accuracy: 0.2446 - val_loss: 2.2144 - val_accuracy: 0.2404
# Epoch 86/200
# 50/50 [==============================] - 23s 451ms/step - loss: 2.2671 - accuracy: 0.2331 - val_loss: 2.2523 - val_accuracy: 0.2374
# Epoch 87/200
# 50/50 [==============================] - 22s 443ms/step - loss: 2.2600 - accuracy: 0.2217 - val_loss: 2.2108 - val_accuracy: 0.2522
# Epoch 88/200
# 50/50 [==============================] - 22s 436ms/step - loss: 2.2765 - accuracy: 0.2280 - val_loss: 2.2674 - val_accuracy: 0.2493
# Epoch 89/200
# 50/50 [==============================] - 22s 441ms/step - loss: 2.2594 - accuracy: 0.2439 - val_loss: 2.2598 - val_accuracy: 0.2404
# Epoch 90/200
# 50/50 [==============================] - 22s 433ms/step - loss: 2.2628 - accuracy: 0.2420 - val_loss: 2.2574 - val_accuracy: 0.2374
# Epoch 91/200
# 50/50 [==============================] - 22s 435ms/step - loss: 2.2182 - accuracy: 0.2420 - val_loss: 2.1797 - val_accuracy: 0.2522
# Epoch 92/200
# 50/50 [==============================] - 22s 435ms/step - loss: 2.2109 - accuracy: 0.2433 - val_loss: 2.1448 - val_accuracy: 0.2789
# Epoch 93/200
# 50/50 [==============================] - 22s 431ms/step - loss: 2.2394 - accuracy: 0.2471 - val_loss: 2.2302 - val_accuracy: 0.2463
# Epoch 94/200
# 50/50 [==============================] - 22s 436ms/step - loss: 2.2701 - accuracy: 0.2401 - val_loss: 2.2453 - val_accuracy: 0.2404
# Epoch 95/200
# 50/50 [==============================] - 22s 440ms/step - loss: 2.2255 - accuracy: 0.2490 - val_loss: 2.2518 - val_accuracy: 0.2315
# Epoch 96/200
# 50/50 [==============================] - 22s 438ms/step - loss: 2.2476 - accuracy: 0.2471 - val_loss: 2.2754 - val_accuracy: 0.2255
# Epoch 97/200
# 50/50 [==============================] - 22s 440ms/step - loss: 2.2289 - accuracy: 0.2484 - val_loss: 2.2083 - val_accuracy: 0.2878
# Epoch 98/200
# 50/50 [==============================] - 22s 442ms/step - loss: 2.2272 - accuracy: 0.2414 - val_loss: 2.1940 - val_accuracy: 0.2730
# Epoch 99/200
# 50/50 [==============================] - 22s 440ms/step - loss: 2.2457 - accuracy: 0.2510 - val_loss: 2.2259 - val_accuracy: 0.2671
# Epoch 100/200
# 50/50 [==============================] - 22s 440ms/step - loss: 2.2050 - accuracy: 0.2401 - val_loss: 2.2628 - val_accuracy: 0.2315
# Epoch 101/200
# 50/50 [==============================] - 22s 436ms/step - loss: 2.2119 - accuracy: 0.2662 - val_loss: 2.2046 - val_accuracy: 0.2493
# Epoch 102/200
# 50/50 [==============================] - 22s 434ms/step - loss: 2.2181 - accuracy: 0.2618 - val_loss: 2.2073 - val_accuracy: 0.2760
# Epoch 103/200
# 50/50 [==============================] - 22s 435ms/step - loss: 2.2395 - accuracy: 0.2369 - val_loss: 2.2674 - val_accuracy: 0.2433
# Epoch 104/200
# 50/50 [==============================] - 22s 433ms/step - loss: 2.2087 - accuracy: 0.2490 - val_loss: 2.2137 - val_accuracy: 0.2700
# Epoch 105/200
# 50/50 [==============================] - 22s 441ms/step - loss: 2.1917 - accuracy: 0.2631 - val_loss: 2.1552 - val_accuracy: 0.2730
# Epoch 106/200
# 50/50 [==============================] - 22s 442ms/step - loss: 2.1991 - accuracy: 0.2529 - val_loss: 2.2103 - val_accuracy: 0.2463
# Epoch 107/200
# 50/50 [==============================] - 22s 442ms/step - loss: 2.1827 - accuracy: 0.2669 - val_loss: 2.2244 - val_accuracy: 0.2374
# Epoch 108/200
# 50/50 [==============================] - 22s 437ms/step - loss: 2.2097 - accuracy: 0.2471 - val_loss: 2.1827 - val_accuracy: 0.2285
# Epoch 109/200
# 50/50 [==============================] - 22s 440ms/step - loss: 2.2396 - accuracy: 0.2414 - val_loss: 2.1594 - val_accuracy: 0.2641
# Epoch 110/200
# 50/50 [==============================] - 22s 441ms/step - loss: 2.2295 - accuracy: 0.2529 - val_loss: 2.1654 - val_accuracy: 0.2760
# Epoch 111/200
# 50/50 [==============================] - 22s 441ms/step - loss: 2.1807 - accuracy: 0.2618 - val_loss: 2.3827 - val_accuracy: 0.2166
# Epoch 112/200
# 50/50 [==============================] - 22s 435ms/step - loss: 2.2328 - accuracy: 0.2548 - val_loss: 2.2325 - val_accuracy: 0.2522
# Epoch 113/200
# 50/50 [==============================] - 22s 435ms/step - loss: 2.2257 - accuracy: 0.2516 - val_loss: 2.3088 - val_accuracy: 0.2285
# Epoch 114/200
# 50/50 [==============================] - 22s 434ms/step - loss: 2.1976 - accuracy: 0.2465 - val_loss: 2.1458 - val_accuracy: 0.3056
# Epoch 115/200
# 50/50 [==============================] - 22s 439ms/step - loss: 2.1837 - accuracy: 0.2752 - val_loss: 2.1255 - val_accuracy: 0.2849
# Epoch 116/200
# 50/50 [==============================] - 22s 439ms/step - loss: 2.1811 - accuracy: 0.2605 - val_loss: 2.2357 - val_accuracy: 0.2196
# Epoch 117/200
# 50/50 [==============================] - 22s 445ms/step - loss: 2.1729 - accuracy: 0.2650 - val_loss: 2.1706 - val_accuracy: 0.2938
# Epoch 118/200
# 50/50 [==============================] - 22s 439ms/step - loss: 2.1724 - accuracy: 0.2656 - val_loss: 2.1879 - val_accuracy: 0.2760
# Epoch 119/200
# 50/50 [==============================] - 22s 440ms/step - loss: 2.1996 - accuracy: 0.2701 - val_loss: 2.1610 - val_accuracy: 0.2997
# Epoch 120/200
# 50/50 [==============================] - 22s 440ms/step - loss: 2.1767 - accuracy: 0.2567 - val_loss: 2.2423 - val_accuracy: 0.2344
# Epoch 121/200
# 50/50 [==============================] - 22s 438ms/step - loss: 2.1758 - accuracy: 0.2624 - val_loss: 2.1955 - val_accuracy: 0.2789
# Epoch 122/200
# 50/50 [==============================] - 22s 440ms/step - loss: 2.1810 - accuracy: 0.2573 - val_loss: 2.2339 - val_accuracy: 0.2493
# Epoch 123/200
# 50/50 [==============================] - 22s 433ms/step - loss: 2.1882 - accuracy: 0.2586 - val_loss: 2.1752 - val_accuracy: 0.2967
# Epoch 124/200
# 50/50 [==============================] - 22s 435ms/step - loss: 2.1480 - accuracy: 0.2745 - val_loss: 2.1388 - val_accuracy: 0.2997
# Epoch 125/200
# 50/50 [==============================] - 22s 434ms/step - loss: 2.1338 - accuracy: 0.2662 - val_loss: 2.1616 - val_accuracy: 0.3027
# Epoch 126/200
# 50/50 [==============================] - 22s 436ms/step - loss: 2.2299 - accuracy: 0.2503 - val_loss: 2.1843 - val_accuracy: 0.2819
# Epoch 127/200
# 50/50 [==============================] - 22s 438ms/step - loss: 2.2222 - accuracy: 0.2669 - val_loss: 2.1528 - val_accuracy: 0.3086
# Epoch 128/200
# 50/50 [==============================] - 22s 444ms/step - loss: 2.1795 - accuracy: 0.2726 - val_loss: 2.1087 - val_accuracy: 0.2967
# Epoch 129/200
# 50/50 [==============================] - 22s 440ms/step - loss: 2.1933 - accuracy: 0.2656 - val_loss: 2.1366 - val_accuracy: 0.2760
# Epoch 130/200
# 50/50 [==============================] - 22s 438ms/step - loss: 2.1762 - accuracy: 0.2535 - val_loss: 2.2205 - val_accuracy: 0.2671
# Epoch 131/200
# 50/50 [==============================] - 22s 440ms/step - loss: 2.1442 - accuracy: 0.2796 - val_loss: 2.1461 - val_accuracy: 0.2967
# Epoch 132/200
# 50/50 [==============================] - 22s 441ms/step - loss: 2.1340 - accuracy: 0.2879 - val_loss: 2.2109 - val_accuracy: 0.2671
# Epoch 133/200
# 50/50 [==============================] - 22s 443ms/step - loss: 2.1464 - accuracy: 0.2694 - val_loss: 2.1658 - val_accuracy: 0.2819
# Epoch 134/200
# 50/50 [==============================] - 22s 440ms/step - loss: 2.1210 - accuracy: 0.2924 - val_loss: 2.1821 - val_accuracy: 0.2641
# Epoch 135/200
# 50/50 [==============================] - 22s 435ms/step - loss: 2.1545 - accuracy: 0.2796 - val_loss: 2.1691 - val_accuracy: 0.2938
# Epoch 136/200
# 50/50 [==============================] - 22s 434ms/step - loss: 2.1506 - accuracy: 0.2758 - val_loss: 2.1547 - val_accuracy: 0.2819
# Epoch 137/200
# 50/50 [==============================] - 22s 436ms/step - loss: 2.1470 - accuracy: 0.2694 - val_loss: 2.2682 - val_accuracy: 0.2285
# Epoch 138/200
# 50/50 [==============================] - 22s 440ms/step - loss: 2.1370 - accuracy: 0.2834 - val_loss: 2.1584 - val_accuracy: 0.2789
# Epoch 139/200
# 50/50 [==============================] - 22s 442ms/step - loss: 2.1263 - accuracy: 0.2713 - val_loss: 2.1150 - val_accuracy: 0.2967
# Epoch 140/200
# 50/50 [==============================] - 22s 438ms/step - loss: 2.1589 - accuracy: 0.2732 - val_loss: 2.2146 - val_accuracy: 0.2433
# Epoch 141/200
# 50/50 [==============================] - 22s 442ms/step - loss: 2.1333 - accuracy: 0.2822 - val_loss: 2.2128 - val_accuracy: 0.2582
# Epoch 142/200
# 50/50 [==============================] - 22s 441ms/step - loss: 2.1171 - accuracy: 0.2892 - val_loss: 2.2031 - val_accuracy: 0.2641
# Epoch 143/200
# 50/50 [==============================] - 22s 445ms/step - loss: 2.1038 - accuracy: 0.2885 - val_loss: 2.1797 - val_accuracy: 0.2433
# Epoch 144/200
# 50/50 [==============================] - 22s 439ms/step - loss: 2.1157 - accuracy: 0.2841 - val_loss: 2.1927 - val_accuracy: 0.2819
# Epoch 145/200
# 50/50 [==============================] - 22s 438ms/step - loss: 2.1470 - accuracy: 0.2688 - val_loss: 2.2298 - val_accuracy: 0.2641
# Epoch 146/200
# 50/50 [==============================] - 22s 431ms/step - loss: 2.1028 - accuracy: 0.2854 - val_loss: 2.1081 - val_accuracy: 0.2878
# Epoch 147/200
# 50/50 [==============================] - 22s 432ms/step - loss: 2.1035 - accuracy: 0.3108 - val_loss: 2.2403 - val_accuracy: 0.2582
# Epoch 148/200
# 50/50 [==============================] - 22s 434ms/step - loss: 2.1085 - accuracy: 0.2841 - val_loss: 2.0964 - val_accuracy: 0.2938
# Epoch 149/200
# 50/50 [==============================] - 22s 441ms/step - loss: 2.0425 - accuracy: 0.3191 - val_loss: 2.1286 - val_accuracy: 0.2789
# Epoch 150/200
# 50/50 [==============================] - 22s 438ms/step - loss: 2.0341 - accuracy: 0.3089 - val_loss: 2.1786 - val_accuracy: 0.2700
# Epoch 151/200
# 50/50 [==============================] - 22s 441ms/step - loss: 2.0655 - accuracy: 0.2936 - val_loss: 2.1492 - val_accuracy: 0.2789
# Epoch 152/200
# 50/50 [==============================] - 22s 441ms/step - loss: 2.0489 - accuracy: 0.3134 - val_loss: 2.1264 - val_accuracy: 0.2878
# Epoch 153/200
# 50/50 [==============================] - 22s 443ms/step - loss: 2.0774 - accuracy: 0.2994 - val_loss: 2.1127 - val_accuracy: 0.2908
# Epoch 154/200
# 50/50 [==============================] - 22s 439ms/step - loss: 2.0360 - accuracy: 0.3076 - val_loss: 2.2000 - val_accuracy: 0.2344
# Epoch 155/200
# 50/50 [==============================] - 22s 439ms/step - loss: 2.0272 - accuracy: 0.3166 - val_loss: 2.0619 - val_accuracy: 0.2760
# Epoch 156/200
# 50/50 [==============================] - 22s 435ms/step - loss: 2.0776 - accuracy: 0.2968 - val_loss: 2.0742 - val_accuracy: 0.2730
# Epoch 157/200
# 50/50 [==============================] - 22s 435ms/step - loss: 2.0121 - accuracy: 0.3395 - val_loss: 2.0655 - val_accuracy: 0.2819
# Epoch 158/200
# 50/50 [==============================] - 22s 434ms/step - loss: 2.0151 - accuracy: 0.3344 - val_loss: 2.0567 - val_accuracy: 0.3175
# Epoch 159/200
# 50/50 [==============================] - 22s 439ms/step - loss: 2.0040 - accuracy: 0.3338 - val_loss: 2.0802 - val_accuracy: 0.2938
# Epoch 160/200
# 50/50 [==============================] - 22s 440ms/step - loss: 2.0319 - accuracy: 0.3153 - val_loss: 2.0005 - val_accuracy: 0.3056
# Epoch 161/200
# 50/50 [==============================] - 22s 442ms/step - loss: 1.9791 - accuracy: 0.3414 - val_loss: 2.0566 - val_accuracy: 0.3027
# Epoch 162/200
# 50/50 [==============================] - 22s 438ms/step - loss: 1.9979 - accuracy: 0.3350 - val_loss: 2.0057 - val_accuracy: 0.3145
# Epoch 163/200
# 50/50 [==============================] - 22s 441ms/step - loss: 1.9608 - accuracy: 0.3510 - val_loss: 2.0843 - val_accuracy: 0.3323
# Epoch 164/200
# 50/50 [==============================] - 22s 443ms/step - loss: 2.0085 - accuracy: 0.3210 - val_loss: 2.1086 - val_accuracy: 0.2997
# Epoch 165/200
# 50/50 [==============================] - 22s 440ms/step - loss: 1.9940 - accuracy: 0.3408 - val_loss: 2.0582 - val_accuracy: 0.2908
# Epoch 166/200
# 50/50 [==============================] - 22s 444ms/step - loss: 1.9826 - accuracy: 0.3433 - val_loss: 1.9794 - val_accuracy: 0.3294
# Epoch 167/200
# 50/50 [==============================] - 22s 433ms/step - loss: 1.9831 - accuracy: 0.3408 - val_loss: 2.0025 - val_accuracy: 0.3175
# Epoch 168/200
# 50/50 [==============================] - 22s 434ms/step - loss: 1.9523 - accuracy: 0.3439 - val_loss: 2.0325 - val_accuracy: 0.3353
# Epoch 169/200
# 50/50 [==============================] - 22s 437ms/step - loss: 1.9200 - accuracy: 0.3605 - val_loss: 1.9858 - val_accuracy: 0.3323
# Epoch 170/200
# 50/50 [==============================] - 22s 433ms/step - loss: 1.9002 - accuracy: 0.3592 - val_loss: 2.0112 - val_accuracy: 0.3620
# Epoch 171/200
# 50/50 [==============================] - 22s 446ms/step - loss: 1.8658 - accuracy: 0.3592 - val_loss: 2.0067 - val_accuracy: 0.3412
# Epoch 172/200
# 50/50 [==============================] - 22s 441ms/step - loss: 1.9219 - accuracy: 0.3484 - val_loss: 2.0032 - val_accuracy: 0.3383
# Epoch 173/200
# 50/50 [==============================] - 22s 442ms/step - loss: 1.9774 - accuracy: 0.3561 - val_loss: 2.0554 - val_accuracy: 0.3027
# Epoch 174/200
# 50/50 [==============================] - 22s 443ms/step - loss: 1.9325 - accuracy: 0.3433 - val_loss: 1.9619 - val_accuracy: 0.3264
# Epoch 175/200
# 50/50 [==============================] - 22s 441ms/step - loss: 1.9520 - accuracy: 0.3408 - val_loss: 1.9900 - val_accuracy: 0.3412
# Epoch 176/200
# 50/50 [==============================] - 22s 443ms/step - loss: 1.9159 - accuracy: 0.3631 - val_loss: 1.9349 - val_accuracy: 0.3561
# Epoch 177/200
# 50/50 [==============================] - 22s 437ms/step - loss: 1.8897 - accuracy: 0.3675 - val_loss: 1.9057 - val_accuracy: 0.3472
# Epoch 178/200
# 50/50 [==============================] - 22s 435ms/step - loss: 1.8600 - accuracy: 0.3847 - val_loss: 1.9166 - val_accuracy: 0.3887
# Epoch 179/200
# 50/50 [==============================] - 22s 437ms/step - loss: 1.8623 - accuracy: 0.3841 - val_loss: 1.9403 - val_accuracy: 0.3620
# Epoch 180/200
# 50/50 [==============================] - 22s 434ms/step - loss: 1.8866 - accuracy: 0.3605 - val_loss: 1.8916 - val_accuracy: 0.3650
# Epoch 181/200
# 50/50 [==============================] - 22s 436ms/step - loss: 1.8722 - accuracy: 0.3694 - val_loss: 1.9783 - val_accuracy: 0.3442
# Epoch 182/200
# 50/50 [==============================] - 22s 442ms/step - loss: 1.8661 - accuracy: 0.3675 - val_loss: 2.0027 - val_accuracy: 0.3234
# Epoch 183/200
# 50/50 [==============================] - 22s 442ms/step - loss: 1.8623 - accuracy: 0.3694 - val_loss: 1.9370 - val_accuracy: 0.3887
# Epoch 184/200
# 50/50 [==============================] - 22s 441ms/step - loss: 1.8278 - accuracy: 0.3828 - val_loss: 1.9520 - val_accuracy: 0.3798
# Epoch 185/200
# 50/50 [==============================] - 22s 443ms/step - loss: 1.8360 - accuracy: 0.3752 - val_loss: 2.1613 - val_accuracy: 0.3472
# Epoch 186/200
# 50/50 [==============================] - 22s 443ms/step - loss: 1.8453 - accuracy: 0.3803 - val_loss: 1.9233 - val_accuracy: 0.3798
# Epoch 187/200
# 50/50 [==============================] - 22s 434ms/step - loss: 1.8190 - accuracy: 0.3885 - val_loss: 1.9065 - val_accuracy: 0.3769
# Epoch 188/200
# 50/50 [==============================] - 22s 438ms/step - loss: 1.8330 - accuracy: 0.3898 - val_loss: 1.8929 - val_accuracy: 0.3858
# Epoch 189/200
# 50/50 [==============================] - 22s 433ms/step - loss: 1.8422 - accuracy: 0.3930 - val_loss: 1.9668 - val_accuracy: 0.3680
# Epoch 190/200
# 50/50 [==============================] - 22s 436ms/step - loss: 1.8958 - accuracy: 0.3726 - val_loss: 1.9032 - val_accuracy: 0.3531
# Epoch 191/200
# 50/50 [==============================] - 22s 440ms/step - loss: 1.8143 - accuracy: 0.3924 - val_loss: 1.9695 - val_accuracy: 0.3412
# Epoch 192/200
# 50/50 [==============================] - 22s 440ms/step - loss: 1.8496 - accuracy: 0.3783 - val_loss: 1.9807 - val_accuracy: 0.3531
# Epoch 193/200
# 50/50 [==============================] - 22s 442ms/step - loss: 1.8604 - accuracy: 0.3745 - val_loss: 1.8443 - val_accuracy: 0.3917
# Epoch 194/200
# 50/50 [==============================] - 22s 439ms/step - loss: 1.8090 - accuracy: 0.4064 - val_loss: 1.9163 - val_accuracy: 0.3798
# Epoch 195/200
# 50/50 [==============================] - 22s 443ms/step - loss: 1.7882 - accuracy: 0.4076 - val_loss: 1.9627 - val_accuracy: 0.3501
# Epoch 196/200
# 50/50 [==============================] - 22s 444ms/step - loss: 1.8450 - accuracy: 0.3669 - val_loss: 1.9839 - val_accuracy: 0.3383
# Epoch 197/200
# 50/50 [==============================] - 22s 439ms/step - loss: 1.8116 - accuracy: 0.3752 - val_loss: 1.8162 - val_accuracy: 0.3858
# Epoch 198/200
# 50/50 [==============================] - 22s 437ms/step - loss: 1.7621 - accuracy: 0.4102 - val_loss: 1.8025 - val_accuracy: 0.3709
# Epoch 199/200
# 50/50 [==============================] - 22s 438ms/step - loss: 1.8216 - accuracy: 0.3866 - val_loss: 1.9170 - val_accuracy: 0.3769
# Epoch 200/200
# 50/50 [==============================] - 22s 438ms/step - loss: 1.7451 - accuracy: 0.4115 - val_loss: 1.8271 - val_accuracy: 0.4214

# %%
print("Accuracy of the model on train data is {:.2f}%".format(history.history["accuracy"][-1]*100))
# Out:
# Accuracy of the model on train data is 41.15%

# %%
import matplotlib.pyplot as plt
acc=history.history['accuracy']
val_acc=history.history['val_accuracy']
loss=history.history['loss']
val_loss=history.history['val_loss']

epochs=range(len(acc))

fig = plt.figure(figsize=(14,7))
plt.plot(epochs, acc, 'r', label="Training Accuracy")
plt.plot(epochs, val_acc, 'b', label="Validation Accuracy")
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and validation accuracy')
plt.legend(loc='lower right')
plt.show()

# %%
fig2 = plt.figure(figsize=(14,7))
plt.plot(epochs, loss, 'r', label="Training Loss")
plt.plot(epochs, val_loss, 'b', label="Validation Loss")
plt.legend(loc='upper right')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and validation loss')
# Out:
# Text(0.5, 1.0, 'Training and validation loss')

# %% [markdown]
# Save Model

# %%
# model.save('/content/drive/MyDrive/indosnake/model/snake_model.h5')

# %%
modelku = '/content/drive/MyDrive/Colab Notebooks/indosnake/snake_model2.tflite'
tf_lite_converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = tf_lite_converter.convert()

tflite_model_name = modelku
open(tflite_model_name, "wb").write(tflite_model)
# Out:
# WARNING:absl:Found untraced functions such as dropout_layer_call_fn, dropout_layer_call_and_return_conditional_losses, dropout_1_layer_call_fn, dropout_1_layer_call_and_return_conditional_losses, dropout_2_layer_call_fn while saving (showing 5 of 20). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /tmp/tmpdqxaqbrl/assets
# INFO:tensorflow:Assets written to: /tmp/tmpdqxaqbrl/assets
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-14-b636a3ccafd7> in <module>()
#       4
#       5 tflite_model_name = modelku
# ----> 6 open(tflite_model_name, "wb").write(tflite_model)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/Colab Notebooks/indosnake/snake_model.tflite'

# %%
valid = '/content/drive/MyDrive/Indo_snake/Single Pred/'
test_img = os.listdir(os.path.join(valid))

test_df = pd.DataFrame({'Image': test_img})
test_df.head()

# %%
valid_gen = ImageDataGenerator(rescale=1./255)

valid_generator = valid_gen.flow_from_dataframe(
    test_df, 
    valid, 
    x_col = 'Image',
    y_col = None,
    class_mode = None,
    target_size = (150, 200),
    batch_size = 1,
    shuffle = False
)

# %%
predict = model.predict_generator(valid_generator, steps = 51)
predict

# %%
# Identifying the classes

label_map = dict((v,k) for k,v in train_generator.class_indices.items())
label_map

# %%
test_df['Label'] = np.argmax(predict, axis = -1)
test_df['Label']

# %%
actual_df = pd.read_csv('/content/drive/MyDrive/Indo_snake/test.csv')
y_true = actual_df['labels']
y_pred = test_df['Label']
print(y_true)

# %%
from sklearn.metrics import confusion_matrix
from mlxtend.plotting import plot_confusion_matrix
cm = confusion_matrix(y_true,y_pred)
plot_confusion_matrix(conf_mat = cm,figsize=(8,7));

# %%
v = random.randint(0, 12)

sample_test = test_df.iloc[v:(v+18)].reset_index(drop = True)
sample_test.head()

plt.figure(figsize=(12, 24))
for index, row in sample_test.iterrows():
    filename = row['Image']
    category = row['Label']
    img = load_img(valid + filename, target_size = (150, 200))
    plt.subplot(6, 3, index + 1)
    plt.imshow(img)
    plt.xlabel(filename + ' ( ' + "{}".format(category) + ' )' )
plt.tight_layout()
plt.show()

# %%
test_df['Label'] = test_df['Label'].replace(label_map)
test_df
